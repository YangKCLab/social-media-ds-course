# %%
from atproto import Client
from datetime import datetime, timedelta, timezone
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
client = Client()
client.login(os.getenv("bluesky_username"), os.getenv("bluesky_password"));

# %%
params = {
    "actor": "yang3kc.bsky.social"
}

# %%
resps = client.app.bsky.graph.get_followers(
    params=params
)

# %%
resps.model_dump()
# Out:
# {'followers': [{'did': 'did:plc:bdqjlf6ijnrpyjz5d3dgz4mv',
#    'handle': 'yuzhelei.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:bdqjlf6ijnrpyjz5d3dgz4mv/bafkreigi7ibbcxflmzldcrohztgggrta43mqglx4h5doxhrjwkmt5pxua4@jpeg',
#    'created_at': '2024-11-21T06:22:30.433Z',
#    'description': 'Ph.D. student at Annenberg School at Penn | Identity, Political Communication, Digital Media | RUC, CUHK, UT Austin alum | Website: yuzhelei.notion.site',
#    'display_name': 'Julian Lei',
#    'indexed_at': '2025-08-24T03:54:15.864Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:bdqjlf6ijnrpyjz5d3dgz4mv/app.bsky.graph.follow/3lx4l7dz2iz26',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:njk3sngvwnzp4zyy4gxgtspd',
#    'handle': 'jolukito.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:njk3sngvwnzp4zyy4gxgtspd/bafkreibu3gbdrtzsrdwdi6cuqtlwcqionwr6kld7ptxjn7mvhsaqpbsgnm@jpeg',
#    'created_at': '2023-08-06T22:54:25.476Z',
#    'description': "Assistant Professor at UT-Austin's School for Journalism and Media | Modern Kilogirl 👩\u200d💻 | Computational Linguistics & Global/US PolComm",
#    'display_name': 'Jo(sephine) Lukito',
#    'indexed_at': '2025-08-21T14:40:17.863Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:njk3sngvwnzp4zyy4gxgtspd/app.bsky.graph.follow/3lwxf6qwjak2q',
#     'following': 'at://did:plc:jqagnoo2ijf75flohmoqbrq4/app.bsky.graph.follow/3lwxc7xcyhs2h',
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:un3hkyukw2mkyhogtkt467a2',
#    'handle': 'vinaykoshy.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:un3hkyukw2mkyhogtkt467a2/bafkreieo6h7zeuan7anuw56y3gd3pgeqslxz3zuyg6la6ceaz2742qweim@jpeg',
#    'created_at': '2025-08-18T21:18:31.763Z',
#    'description': 'Post-doc at UW working on AI for collective decision-making and computational social science. Previously at UIUC and UC Berkeley',
#    'display_name': 'Vinay Koshy',
#    'indexed_at': '2025-08-18T21:25:56.863Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:un3hkyukw2mkyhogtkt467a2/app.bsky.graph.follow/3lwslpz4wns2q',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:4shzx65ffywwawej7jnqs7f6',
#    'handle': 'davideichinger.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:4shzx65ffywwawej7jnqs7f6/bafkreibxetd6nybwginy3tmfktfxsayhycgcwj5jhmor6qhngecn7xgepq@jpeg',
#    'created_at': '2025-01-09T15:16:12.513Z',
#    'description': "I enjoy playing with family, reading science fiction and history, gardening, board games, and jazzercise.  I'm a father, husband, Navy veteran, and graduate student studying computer science at George Mason University. \nMastodon: https://scicomm.xyz/@David",
#    'display_name': 'David Abuín Eichinger',
#    'indexed_at': '2025-08-20T20:40:44.663Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:4shzx65ffywwawej7jnqs7f6/app.bsky.graph.follow/3lwpozdp63w22',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:h5rh5igkd6icg6uk5buo3jae',
#    'handle': 'a.ai',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': {'allow_incoming': 'all',
#      'py_type': 'app.bsky.actor.defs#profileAssociat
bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:zm55kb5w7mgsyvqs6scjylxm/bafkreicqm7hnbxybdo6oqy2hncj2yuopdmiz6dtzariyryzpzydkls4bli@jpeg',
#    'created_at': '2025-01-23T21:56:49.912Z',
#    'description': '- Character Designer\n- Illustrator\n- Film & TV Production\nhttps://asheps.art/\nhttps://instagram.com/ashepsart/',
#    'display_name': 'ASheps Art',
#    'indexed_at': '2025-08-07T19:27:12.364Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:zm55kb5w7mgsyvqs6scjylxm/app.bsky.graph.follow/3lviduc6svz2m',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:b7lx6577xgav26sg3ebhi553',
#    'handle': 'gianluca99.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': {'allow_incoming': 'all',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedChat'},
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:b7lx6577xgav26sg3ebhi553/bafkreidkz5d2bdfq53lwwvfketo3ehp2sqctx3zj65mfmvuaufrybjapem@jpeg',
#    'created_at': '2023-11-23T07:53:38.774Z',
#    'description': 'Enjoying playing with the data. Scientific collaborator at University of Applied Sciences and Arts of Southern Switzerland (SUPSI)\nhttps://gi-ux.github.io/',
#    'display_name': 'Gianluca Nogara',
#    'indexed_at': '2025-07-23T13:57:11.498Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:b7lx6577xgav26sg3ebhi553/app.bsky.graph.follow/3lvaisz557s2d',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:7abg4k6uaqznd6wiwwybm74z',
#    'handle': 'lyh0925.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:7abg4k6uaqznd6wiwwybm74z/bafkreifw2bz5m2phq337zdb6baq67vh2jxczdfge44ic6dhuri3kz4o4ha@jpeg',
#    'created_at': '2025-07-26T07:43:39.963Z',
#    'description': None,
#    'display_name': '',
#    'indexed_at': '2025-07-26T07:43:39.963Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:7abg4k6uaqznd6wiwwybm74z/app.bsky.graph.follow/3luu3f4l5id2e',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:f52kb7npatd7owyqj6u27qrn',
#    'handle': 'bmayank.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:f52kb7npatd7owyqj6u27qrn/bafkreigjozbldbhqch4elxhqeii2ixbuttnid7czjviiukssx5ryutyuci@jpeg',
#    'created_at': '2024-11-14T18:47:19.086Z',
#    'description': None,
#    'display_name': 'Mayank Bhushan',
#    'indexed_at': '2024-12-06T21:55:35.609Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:f52kb7npatd7owyqj6u27qrn/app.bsky.graph.follow/3luq6eie4mv2j',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:pn7deyvzsfixm5sp6lzhfvvf',
#    'handle': 'fmerhout.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': {'allow_incoming': 'following',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedChat'},
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:pn7deyvzsfixm5sp6lzhfvvf/bafkreigm34grv3vdorkcp5c6wbyxygn5ift2ntmka6mo5fgprl6ffc6g34@jpeg',
#    'created_at': '2023-09-10T20:23:54.063Z',
#    'description': 'Sociologist and Social Data Scientist at University of Copenhagen. Duke University PhD. Intergroup relations & computational social science. He/him/his. https://fmerhout.github.io',
#    'display_name': 'Friedolin Merhout',
#    'indexed_at': '2024-02-22T21:48:20.930Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:pn7deyvzsfixm5sp6lzhfvvf/app.bsky.graph.follow/3lujyg5obcv2h',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:tf5jd43pywionew7suwgd2un',
#    'handle': 'sciencehr.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:tf5jd43pywionew7suwgd2un/bafkreibq3xwopbvsmyo5avk6h7khrc2jpdlgvumqxmxdsftule3wlednki@jpeg',
#    'created_at': '2025-05-08T14:43:15.907Z',
#    'description': 'A career network featuring science jobs in academia and industry.\nVisit our platform at www.science.hr',
#    'display_name': 'Science HR',
#    'indexed_at': '2025-07-30T16:31:35.563Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:tf5jd43pywionew7suwgd2un/app.bsky.graph.follow/3luij7latls2t',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:l5rihkp62pudftixuy357aou',
#    'handle': 'joannakapatou46.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:l5rihkp62pudftixuy357aou/bafkreiatd5o3nr2x3stfbh7vraah5ppvf2i4fep7qk4hhdr27vwxk2rkmy@jpeg',
#    'created_at': '2025-03-06T18:26:43.213Z',
#    'description': 'owner12companies one yatch 2jeep car member peirate party',
#    'display_name': '🏳️\u200d🌈',
#    'indexed_at': '2025-08-07T21:18:13.363Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:l5rihkp62pudftixuy357aou/app.bsky.graph.follow/3lu6j5rv5be2p',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:wtqffwnj7bhcxhtomqo6lsad',
#    'handle': 'junioreinsteins.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:wtqffwnj7bhcxhtomqo6lsad/bafkreigv4qiv5dpybtq6vs2whhnfyg5pinupgxqpzankabcnqygwxcikyi@jpeg',
#    'created_at': '2024-11-18T14:07:35.080Z',
#    'description': 'Award-winning Science events for kids. Founded Ireland☘️Scientist & Mum, speaker United Nations 🇺🇳 Hands-on, STEM fun to kids Ireland 🇮🇪 UK 🇬🇧Canada 🇨🇦  Join us as Franchise Owners! Licences for International Schools  junioreinsteinsscienceclub.com',
#    'display_name': 'Junior Einsteins Science Club®',
#    'indexed_at': '2025-08-05T22:01:28.664Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:wtqffwnj7bhcxhtomqo6lsad/app.bsky.graph.follow/3lu4bq4u5xh2l',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:iokkurd552mwggdwng63alkj',
#    'handle': 'ruberri.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:iokkurd552mwggdwng63alkj/bafkreiejxjwjrxj4kvxg4yhh2atn5ktcdrh3zaq3orp2lyhub5x6bvzdii@jpeg',
#    'created_at': '2025-07-12T12:47:40.697Z',
#    'description': 'DH @epfl, prev CS @kaist',
#    'display_name': 'Ngoc (Rubi) Doan',
#    'indexed_at': '2025-07-12T12:51:02.897Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:iokkurd552mwggdwng63alkj/app.bsky.graph.follow/3ltrfma6skw2k',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:2zevabeya3xlhkcichxypyay',
#    'handle': 'lutzoettershagen.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:2zevabeya3xlhkcichxypyay/bafkreigcw5fudp7mg24fuiynwpet66fvukompkpbnkoorizsub5hi6vmkm@jpeg',
#    'created_at': '2025-07-12T03:11:59.898Z',
#    'description': 'Assistant Professor at the Department of Computer Science, University of Liverpool.\n\nhttps://lutzoe.github.io/',
#    'display_name': '',
#    'indexed_at': '2025-07-12T07:53:31.297Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:2zevabeya3xlhkcichxypyay/app.bsky.graph.follow/3ltqffg7txd22',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:ufi2mgfewsxb465g4opmnds5',
#    'handle': 'rasikamurali.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:ufi2mgfewsxb465g4opmnds5/bafkreiaxlsm6sxbw3qlhwjup3yvthtqzxd2tqkpufeunaubejub4g7xmum@jpeg',
#    'created_at': '2024-09-16T16:15:33.847Z',
#    'description': 'PhD Student @ Indiana University Bloomington | Cooperative behaviors on social networks and agentic teams',
#    'display_name': 'Rasika Muralidharan',
#    'indexed_at': '2025-07-08T19:12:52.597Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:ufi2mgfewsxb465g4opmnds5/app.bsky.graph.follow/3lthz6xunv522',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:xnm4b2b5seevfbrpxs6jxuw2',
#    'handle': 'sarahindryaniaziza.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc
z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:e2wiep4uzhu3azuiy74ogaa7/app.bsky.graph.follow/3ls7zx4slw32f',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:xtwf3ta4ddof5crtx5f4zzfe',
#    'handle': 'julaluehring.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:xtwf3ta4ddof5crtx5f4zzfe/bafkreichp3lvn7fofpr4r3rpy2xryrlzvtinnxnq2xha6o5iwzuoazk7hu@jpeg',
#    'created_at': '2023-10-10T07:12:00.181Z',
#    'description': 'Computational communication scientist at the University of Vienna & Complexity Science Hub | alumna UvA ASCoR\nhttps://julaluehring.github.io/',
#    'display_name': 'Jula Luehring',
#    'indexed_at': '2025-04-30T22:25:19.543Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:xtwf3ta4ddof5crtx5f4zzfe/app.bsky.graph.follow/3lrrmqrnnes2w',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:mkqgnhsp35xqzpdu5jwm4cfb',
#    'handle': 'antmandan.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': {'allow_incoming': 'following',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedChat'},
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:mkqgnhsp35xqzpdu5jwm4cfb/bafkreig44vkvse2ykkxuesazq7524vznj73soetisvbfbuukbsbdiiyhfu@jpeg',
#    'created_at': '2023-07-03T05:03:34.097Z',
#    'description': 'Professor of Digital Communication and Director of the QUT Digital Media Research Centre. Cyclist, beer brewer, nerd, community advocate.',
#    'display_name': 'Daniel Angus',
#    'indexed_at': '2025-08-24T18:04:50.963Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:mkqgnhsp35xqzpdu5jwm4cfb/app.bsky.graph.follow/3lro2fg2h4j27',
#     'following': 'at://did:plc:jqagnoo2ijf75flohmoqbrq4/app.bsky.graph.follow/3lrnyypf6ha2x',
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:4wbqurae475sbdj5adivg2jr',
#    'handle': 'rongxinouyang.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:4wbqurae475sbdj5adivg2jr/bafkreieg55xsdnu7r26zjjl7kcxjyr6se5t2f3tgqls5ug6er7uctaqn7m@jpeg',
#    'created_at': '2025-04-14T16:09:00.445Z',
#    'description': 'NUS PhD candidate in Communication\n\nCausal and computational methods to study the societal and political effects of communication technologies\n\nCV: rongxin.me/cv',
#    'display_name': 'Rongxin',
#    'indexed_at': '2025-06-15T09:23:03.807Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:4wbqurae475sbdj5adivg2jr/app.bsky.graph.follow/3lrm7cxjkkt2t',
#     'following': 'at://did:plc:jqagnoo2ijf75flohmoqbrq4/app.bsky.graph.follow/3lrmkotojxr2i',
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:vaoecp2dpziqkc444wdvgfjd',
#    'handle': 'zeningduan.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:vaoecp2dpziqkc444wdvgfjd/bafkreibklrfykzqbykjlhtynqgco2fzdykg7resowicy2os2u2ojlm4kfi@jpeg',
#    'created_at': '2024-11-24T17:44:38.708Z',
#    'description': 'PhD candidate @uw_sjmc | I study #Al & #InfoEngagement on #SocialMedia using & developing #ComputationalMethods | Skier, dad of two cats, #onJobMarket',
#    'display_name': '',
#    'indexed_at': '2024-11-24T17:49:09.909Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:vaoecp2dpziqkc444wdvgfjd/app.bsky.graph.follow/3lra4fck4ds2g',
#     'following': 'at://did:plc:jqagnoo2ijf75flohmoqbrq4/app.bsky.graph.follow/3loj6fmh2mw22',
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:do2dvjyj5woue4sxa2xmbjcq',
#    'handle': 'sophiaaknight.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:do2dvjyj5woue4sxa2xmbjcq/bafkreie4pbyfurgozyzef3rcqytvpaahkq7ptfckhfmdtyrac25fyjuyjy@jpeg',
#    'created_at': '2023-08-18T18:13:02.237Z',
#    'description': 'Research Lead, Civic & Democratic Participation Online at the Responsible Innovation Centre, BBC R&D\n\nBackground in computational social science, looking for PhD opportunities starting in 2026/27\n\nWrote my MSc dissertation on podcasts & politics',
#    'display_name': 'Sophia A. Knight',
#    'indexed_at': '2025-06-23T09:00:53.897Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:do2dvjyj5woue4sxa2xmbjcq/app.bsky.graph.follow/3lqupnfrb5322',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:y4izstifugswkca6hsqdk74o',
#    'handle': 'kmzkk.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:y4izstifugswkca6hsqdk74o/bafkreicsuo5lcdwxhu6igyetmbizh7hywpzo43vmj5f6rm4g5x5kzjavye@jpeg',
#    'created_at': '2025-01-25T00:28:23.713Z',
#    'description': 'Ph.D candidate at UT Austin | Media & communication studies',
#    'display_name': 'kayo mimizuka',
#    'indexed_at': '2025-05-31T16:17:58.806Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:y4izstifugswkca6hsqdk74o/app.bsky.graph.follow/3lqi5febfrr27',
#     'following': 'at://did:plc:jqagnoo2ijf75flohmoqbrq4/app.bsky.graph.follow/3lqijai3df627',
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:yql3sysdxjkhwc6qouxtacug',
#    'handle': 'baottruong.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:yql3sysdxjkhwc6qouxtacug/bafkreicb5ekn6bj7s2prgezabt6vg65miutxwkwusedwr5qpijddfua5ia@jpeg',
#    'created_at': '2024-02-19T22:40:14.652Z',
#    'description': 'Informatics Ph.D candidate at Indiana University Bloomington\nhttps://btrantruong.github.io/',
#    'display_name': 'Bao Truong',
#    'indexed_at': '2025-04-18T22:01:40.344Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:yql3sysdxjkhwc6qouxtacug/app.bsky.graph.follow/3lqdnekhi4h22',
#     'following': 'at://did:plc:jqagnoo2ijf75flohmoqbrq4/app.bsky.graph.follow/3lomlvzdynk26',
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:l64jsajqu6trdsrkph5osajc',
#    'handle': 'giorgospanay.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:l64jsajqu6trdsrkph5osajc/bafkreic575ohcppapjyf2lp6k3ubc3q33pgggywdntghgok22mu4ityk74@jpeg',
#    'created_at': '2024-12-16T20:55:49.513Z',
#    'description': 'Computer science doctorand at Uppsala University, @uuinfolab.bsky.social\u202c. \nMining social networks, discovering new music, occasionally playing baseball and softball. \nProbably not George Michael, but search engines believe otherwise.',
#    'display_name': 'Georgios Panayiotou',
#    'indexed_at': '2025-08-23T16:00:01.564Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:l64jsajqu6trdsrkph5osajc/app.bsky.graph.follow/3lq53d2np4n2k',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:vfply7pch746clh4odo2ivpo',
#    'handle': 'yunhwankim2.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:vfply7pch746clh4odo2ivpo/bafkreiaj54cnejlqhka6fojjyw7rmatfrhkzhpk7uo7oaxcwxvythlngf4@jpeg',
#    'created_at': '2025-04-06T05:00:38.664Z',
#    'description': 'Assistant professor in the College of General Education at Kookmin University, South Korea: collective opinion / cooperation / evolutionary game / agent-based modeling / social media / computational social science.',
#    'display_name': 'Yunhwan Kim',
#    'indexed_at': '2025-05-13T01:38:47.607Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:vfply7pch746clh4odo2ivpo/app.bsky.graph.follow/3lpyjas6mir2r',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:fwks525g7gw5wc7ul2wg4wj5',
#    'handle': 'mims.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:fwks525g7gw5wc7ul2wg4wj5/bafkreih2uhfwmrduowl4g2ps7hmr5s6gavpaxarth66eeqjen37lpopuwy@jpeg',
#    'created_at': '2023-04-26T13:43:19.190Z',
#    'description': "WSJ tech columnist. Dog person. Author of Arriving Today, an unfortunately timely book about the global system of trade we're currently flushing down the toilet: https://www.harpercollins.com/products/arriving-today-christopher-mims",
#    'display_name': 'Christopher Mims',
#    'indexed_at': '2025-08-23T11:53:34.664Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:fwks525g7gw5wc7ul2wg4wj5/app.bsky.graph.follow/3lpxgmeldr727',
#     'following': None,
# ...
#    'created_at': '2024-12-13T14:03:49.712Z',
#    'description': 'CS Phd @sabanciu\n@varollab member\nHaving some knowledge about NLP : )\nI like computers :D\n\n\nnajafi-ali.com',
#    'display_name': 'Ali Najafi',
#    'indexed_at': '2025-05-24T12:03:47.307Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:j2raxnfvdpxddttknbl6yene/app.bsky.graph.follow/3lpwvd3t5na2n',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:dnccdqyiomczwelizodb473z',
#    'handle': 'ernestopriego.com',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:dnccdqyiomczwelizodb473z/bafkreigovvq757wldmh6byvdh45uw2m6k4awsbispjgfzgcoa3mrcddisi@jpeg',
#    'created_at': '2023-09-19T16:07:16.395Z',
#    'description': 'Senior Lecturer @hcid.city. Editor @comicsgrid.com. Currently co-organising @comicsandai.org. Sharing; reposting is not endorsement. Absolutely personal capacity. I am human. UK based. https://linktr.ee/ernestopriego',
#    'display_name': 'Ernesto Priego',
#    'indexed_at': '2025-08-15T14:25:21.663Z',
#    'labels': [{'cts': '1970-01-01T00:00:00.000Z',
#      'src': 'did:plc:dnccdqyiomczwelizodb473z',
#      'uri': 'at://did:plc:dnccdqyiomczwelizodb473z/app.bsky.actor.profile/self',
#      'val': '!no-unauthenticated',
#      'cid': 'bafyreiao7c3uvs77dlbhmo663ouqk2ug4avpcez22dvzvexylpef25cxty',
#      'exp': None,
#      'neg': None,
#      'sig': None,
#      'ver': None,
#      'py_type': 'com.atproto.label.defs#label'}],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:dnccdqyiomczwelizodb473z/app.bsky.graph.follow/3lpwu3cexsp22',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:rlka7jp4jghxye2coac5aj2u',
#    'handle': 'tobiaspreis.com',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:rlka7jp4jghxye2coac5aj2u/bafkreia46ajtpq6iqf3ddzfib2rt32av37mla2wfwndixz6rv5g3ywilve@jpeg',
#    'created_at': '2023-11-22T23:33:16.218Z',
#    'description': 'Professor of Behavioural Science and Finance at the University of Warwick, measuring and predicting human behaviour with online data. Co-director of the Data Science Lab. TEDx: https://youtu.be/nwk0mfpOi_s',
#    'display_name': 'Tobias Preis',
#    'indexed_at': '2025-02-19T16:40:10.612Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:rlka7jp4jghxye2coac5aj2u/app.bsky.graph.follow/3lpahrxwqta2f',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:bya4raqamweb4b5uzenowrog',
#    'handle': 'joesoap.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:bya4raqamweb4b5uzenowrog/bafkreiblaltyqynx43cjtasrq2evmksrnvgeh63grq4gzh5mgizfumvh64@jpeg',
#    'created_at': '2024-08-13T15:51:58.008Z',
#    'description': None,
#    'display_name': '',
#    'indexed_at': '2024-08-13T15:51:58.008Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:bya4raqamweb4b5uzenowrog/app.bsky.graph.follow/3lp7ir2jnss2o',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:5hdt5di3vc4ljafoyqhc4yrk',
#    'handle': 'markdodson.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:5hdt5di3vc4ljafoyqhc4yrk/bafkreihoqftsmfqq3ajfd5j7ktfmanyrbkvu2ntoaizsbtr5ryzf35uvuy@jpeg',
#    'created_at': '2024-11-17T18:07:38.662Z',
#    'description': 'Founder of Cypress Capital - www.cypresscapital.com',
#    'display_name': 'Mark Dodson',
#    'indexed_at': '2025-07-27T13:52:54.263Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:5hdt5di3vc4ljafoyqhc4yrk/app.bsky.graph.follow/3lp7a523e542m',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:jb4kk76qkpndj7oleee5kjro',
#    'handle': 'ruggsea.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:jb4kk76qkpndj7oleee5kjro/bafkreifxj5ucjh22oxmtrpqnlolfk4ghx6amimargpr74jtwk7xbuexefu@jpeg',
#    'created_at': '2025-02-04T18:07:59.813Z',
#    'description': 'AI/NLP research at @uni-graz.at, (Data) Journalism for scomodo.org.\n\nBefore: AI policy & Data science @_interface_eu, geopolitical analysis for @Geopoliticainfo',
#    'display_name': 'ruggsea',
#    'indexed_at': '2025-03-26T06:59:42.963Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:jb4kk76qkpndj7oleee5kjro/app.bsky.graph.follow/3lp77u6q5eg2h',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:t6cx47svdvun6tf7ajjmihfs',
#    'handle': 'helene-zgc.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:t6cx47svdvun6tf7ajjmihfs/bafkreighhwdgxbpiex6cn5qztw2bx5x7koalhpuydxrng2ncy3gdyo3yby@jpeg',
#    'created_at': '2024-11-17T09:05:07.960Z',
#    'description': 'Economist (prospective modeling for climate economics). Currently studying Fundamental and Applied Mathematics at @upcite.bsky.social\n\nInterested in everything around collective cognition and action and its mathematical formalisation',
#    'display_name': 'Hélène',
#    'indexed_at': '2025-05-08T11:11:21.807Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:t6cx47svdvun6tf7ajjmihfs/app.bsky.graph.follow/3lonpggh46v27',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:mmx6j4bbuwlegny7h3u2lyzd',
#    'handle': 'samgoree.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': {'allow_incoming': 'all',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedChat'},
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:mmx6j4bbuwlegny7h3u2lyzd/bafkreigg4aqdc7gd5hs5audawvjpvuh6nymygyysdtj44icgdq6dzja3o4@jpeg',
#    'created_at': '2024-02-07T13:09:30.456Z',
#    'description': 'Interested in things that are both computational and qualitative, especially surrounding AI. Assistant professor of computer science at Stonehill College, he/him https://samgoree.github.io',
#    'display_name': 'Sam Goree',
#    'indexed_at': '2024-11-17T19:41:43.773Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:mmx6j4bbuwlegny7h3u2lyzd/app.bsky.graph.follow/3lomoenymtl2v',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:rraivjvydtbpniqdibudmmyx',
#    'handle': 'maxpi.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': {'allow_incoming': 'following',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedChat'},
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:rraivjvydtbpniqdibudmmyx/bafkreiek2cknzcduus262jbl3dgohgvmvmas7enxwfquom2i6yccm4gr54@jpeg',
#    'created_at': '2023-09-21T09:06:26.008Z',
#    'description': 'interested in sociology, computational social sciences, criminology, causal inference, spatial analysis and more | #rstats | he/him',
#    'display_name': 'Max Pickartz 📊',
#    'indexed_at': '2025-07-23T12:46:56.398Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:rraivjvydtbpniqdibudmmyx/app.bsky.graph.follow/3lo4jemify32x',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:42zg7ajsfp4mv4klwt26f5m6',
#    'handle': 'moosewin.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:42zg7ajsfp4mv4klwt26f5m6/bafkreigjw4l5jbf4yujtclvyybgcijewy25lpc7iuf2z4hqqpcno4nrnkm@jpeg',
#    'created_at': '2023-06-03T03:03:45.046Z',
#    'description': 'DOGE-displaced former civil servant technologist, current developer on analytics/stats for private and nonprofit sector. Amateur poet, recreational philosopher of math, and former photographer.\n\nthey/she. 🚄🏳️\u200d🌈\nhttps://povertyofattention.com/',
#    'display_name': 'L. Eleanor "Moose" Nguyen',
#    'indexed_at': '2025-05-12T09:03:59.807Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:42zg7ajsfp4mv4klwt26f5m6/app.bsky.graph.follow/3lo3or2q7da2l',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'},
#   {'did': 'did:plc:fy545twzlu22wgtzra6lh47f',
#    'handle': 'justanormaldino.bsky.social',
#    'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#      'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#     'chat': None,
#     'feedgens': None,
#     'labeler': None,
#     'lists': None,
#     'starter_packs': None,
#     'py_type': 'app.bsky.actor.defs#profileAssociated'},
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:fy545twzlu22wgtzra6lh47f/bafkreihdd6jne6b6ead53ebayok3gjw5r5zio322p7isuqxcvmywlhn72a@jpeg',
#    'created_at': '2023-12-08T08:40:19.871Z',
#    'description': 'Postdoc at ETHz - Associate Editor HSScomms\n\nExploring Opinion Dynamics and Collective Intelligence with social simulations and belief networks.',
#    'display_name': 'Dino Carpentras',
#    'indexed_at': '2025-03-10T11:13:59.512Z',
#    'labels': [],
#    'status': None,
#    'verification': None,
#    'viewer': {'activity_subscription': None,
#     'blocked_by': False,
#     'blocking': None,
#     'blocking_by_list': None,
#     'followed_by': 'at://did:plc:fy545twzlu22wgtzra6lh47f/app.bsky.graph.follow/3lnzgfhoukx2i',
#     'following': None,
#     'known_followers': None,
#     'muted': False,
#     'muted_by_list': None,
#     'py_type': 'app.bsky.actor.defs#viewerState'},
#    'py_type': 'app.bsky.actor.defs#profileView'}],
#  'subject': {'did': 'did:plc:jqagnoo2ijf75flohmoqbrq4',
#   'handle': 'yang3kc.bsky.social',
#   'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#     'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#    'chat': None,
#    'feedgens': None,
#    'labeler': None,
#    'lists': None,
#    'starter_packs': None,
#    'py_type': 'app.bsky.actor.defs#profileAssociated'},
#   'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:jqagnoo2ijf75flohmoqbrq4/bafkreigofi3h6mmxglqwlgbav6vqnlufrpdj7jup5svqw4oekl2moonnpi@jpeg',
#   'created_at': '2023-08-16T15:06:26.185Z',
#   'description': 'Kaicheng Yang, PhD | Assistant professor @Binghamton University CS | Computational social science, bots, +  | views mine',
#   'display_name': 'Kevin Yang',
#   'indexed_at': '2025-08-15T03:46:08.264Z',
#   'labels': [],
#   'status': None,
#   'verification': None,
#   'viewer': {'activity_subscription': None,
#    'blocked_by': False,
#    'blocking': None,
#    'blocking_by_list': None,
#    'followed_by': None,
#    'following': None,
#    'known_followers': None,
#    'muted': False,
#    'muted_by_list': None,
#    'py_type': 'app.bsky.actor.defs#viewerState'},
#   'py_type': 'app.bsky.actor.defs#profileView'},
#  'cursor': '3lnm6he2grh2q'}
