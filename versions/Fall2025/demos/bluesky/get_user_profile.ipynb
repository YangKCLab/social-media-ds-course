# %%
from atproto import Client
from datetime import datetime, timedelta, timezone
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
client = Client()
client.login(os.getenv("bluesky_username"), os.getenv("bluesky_password"));

# %%
params = {
    "actor": "yang3kc.bsky.social"
}

# %%
resps = client.app.bsky.graph.get_profile(
    params=params
)

# %%
resps.model_dump()
# Out:
# {'did': 'did:plc:jqagnoo2ijf75flohmoqbrq4',
#  'handle': 'yang3kc.bsky.social',
#  'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#    'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#   'chat': None,
#   'feedgens': 0,
#   'labeler': False,
#   'lists': 0,
#   'starter_packs': 0,
#   'py_type': 'app.bsky.actor.defs#profileAssociated'},
#  'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:jqagnoo2ijf75flohmoqbrq4/bafkreigofi3h6mmxglqwlgbav6vqnlufrpdj7jup5svqw4oekl2moonnpi@jpeg',
#  'banner': None,
#  'created_at': '2023-08-16T15:06:26.185Z',
#  'description': 'Kaicheng Yang, PhD | Assistant professor @Binghamton University CS | Computational social science, bots, +  | views mine',
#  'display_name': 'Kevin Yang',
#  'followers_count': 693,
#  'follows_count': 397,
#  'indexed_at': '2025-08-15T03:46:08.264Z',
#  'joined_via_starter_pack': None,
#  'labels': [],
#  'pinned_post': None,
#  'posts_count': 93,
#  'status': None,
#  'verification': None,
#  'viewer': {'activity_subscription': None,
#   'blocked_by': False,
#   'blocking': None,
#   'blocking_by_list': None,
#   'followed_by': None,
#   'following': None,
#   'known_followers': {'count': 148,
#    'followers': [{'did': 'did:plc:z2bg7yzpjr5bgfnzxmgcmyvw',
#      'handle': 'dmimno.bsky.social',
#      'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#        'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#       'chat': {'allow_incoming': 'following',
#        'py_type': 'app.bsky.actor.defs#profileAssociatedChat'},
#       'feedgens': None,
#       'labeler': None,
#       'lists': None,
#       'starter_packs': None,
#       'py_type': 'app.bsky.actor.defs#profileAssociated'},
#      'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:z2bg7yzpjr5bgfnzxmgcmyvw/bafkreighz3frnpfnbq5lytgpojgvvqjfho43ayj6ao7ubmckmldnchazje@jpeg',
#      'created_at': '2023-07-03T16:09:12.073Z',
#      'display_name': 'David Mimno',
#      'labels': [],
#      'status': None,
#      'verification': None,
#      'viewer': {'activity_subscription': None,
#       'blocked_by': False,
#       'blocking': None,
#       'blocking_by_list': None,
#       'followed_by': 'at://did:plc:z2bg7yzpjr5bgfnzxmgcmyvw/app.bsky.graph.follow/3lawggbgqqb2f',
#       'following': 'at://did:plc:jqagnoo2ijf75flohmoqbrq4/app.bsky.graph.follow/3law4qonomo2w',
#       'known_followers': None,
#       'muted': False,
#       'muted_by_list': None,
#       'py_type': 'app.bsky.actor.defs#viewerState'},
#      'py_type': 'app.bsky.actor.defs#profileViewBasic'},
#     {'did': 'did:plc:oxymql65kmeao5ary5pko72n',
#      'handle': 'rnv.bsky.social',
#      'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#        'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#       'chat': None,
#       'feedgens': None,
#       'labeler': None,
#       'lists': None,
#       'starter_packs': None,
#       'py_type': 'app.bsky.actor.defs#profileAssociated'},
#      'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:oxymql65kmeao5ary5pko72n/bafkreie3w4b4mucjrwtbzn3rwcvva3lh7tceqskpwjj6bplivsoyzuydpq@jpeg',
#      'created_at': '2023-09-20T14:19:36.681Z',
#      'display_name': 'Arnav Arora',
#      'labels': [],
#      'status': None,
#      'verification': None,
#      'viewer': {'activity_subscription': None,
#       'blocked_by': False,
#       'blocking': None,
#       'blocking_by_list': None,
#       'followed_by': 'at://did:plc:oxymql65kmeao5ary5pko72n/app.bsky.graph.follow/3lkvvfm5hib24',
#       'following': 'at://did:plc:jqagnoo2ijf75flohmoqbrq4/app.bsky.graph.follow/3law4qonolj2w',
#       'known_followers': None,
#       'muted': False,
#       'muted_by_list': None,
#       'py_type': 'app.bsky.actor.defs#viewerState'},
#      'py_type': 'app.bsky.actor.defs#profileViewBasic'},
#     {'did': 'did:plc:65krso44il64qt7a4khzt5dm',
#      'handle': 'ndiakopoulos.bsky.social',
#      'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#        'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#       'chat': {'allow_incoming': 'following',
#        'py_type': 'app.bsky.actor.defs#profileAssociatedChat'},
#       'feedgens': None,
#       'labeler': None,
#       'lists': None,
#       'starter_packs': None,
#       'py_type': 'app.bsky.actor.defs#profileAssociated'},
#      'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:65krso44il64qt7a4khzt5dm/bafkreid5mctkrqrq64d4my67f7wmgvayhr7v5kgavs7dufkcqbsqdg42rq@jpeg',
#      'created_at': '2023-05-01T21:08:31.849Z',
#      'display_name': 'Nick Diakopoulos',
#      'labels': [],
#      'status': None,
#      'verification': None,
#      'viewer': {'activity_subscription': None,
#       'blocked_by': False,
#       'blocking': None,
#       'blocking_by_list': None,
#       'followed_by': 'at://did:plc:65krso44il64qt7a4khzt5dm/app.bsky.graph.follow/3lbdhae5yey2p',
#       'following': 'at://did:plc:jqagnoo2ijf75flohmoqbrq4/app.bsky.graph.follow/3lauwdmhcks2m',
#       'known_followers': None,
#       'muted': False,
#       'muted_by_list': None,
#       'py_type': 'app.bsky.actor.defs#viewerState'},
#      'py_type': 'app.bsky.actor.defs#profileViewBasic'},
#     {'did': 'did:plc:wk7sybhegd37i7ljsltxbef6',
#      'handle': 'justinhendrix.bsky.social',
#      'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#        'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#       'chat': {'allow_incoming': 'following',
#        'py_type': 'app.bsky.actor.defs#profileAssociatedChat'},
#       'feedgens': None,
#       'labeler': None,
#       'lists': None,
#       'starter_packs': None,
#       'py_type': 'app.bsky.actor.defs#profileAssociated'},
#      'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:wk7sybhegd37i7ljsltxbef6/bafkreicefebwq2tgemncb3vxpycbjzni6haztqie2ufdheshv4bworii24@jpeg',
#      'created_at': '2023-04-28T00:53:22.305Z',
#      'display_name': 'Justin Hendrix',
#      'labels': [],
#      'status': None,
#      'verification': {'trusted_verifier_status': 'none',
#       'verifications': [{'created_at': '2025-07-30T19:51:07.899Z',
#         'is_valid': True,
#         'issuer': 'did:plc:z72i7hdynmk6r22z27h6tvur',
#         'uri': 'at://did:plc:z72i7hdynmk6r22z27h6tvur/app.bsky.graph.verification/3lv7fgd345f2t',
#         'py_type': 'app.bsky.actor.defs#verificationView'}],
#       'verified_status': 'valid',
#       'py_type': 'app.bsky.actor.defs#verificationState'},
#      'viewer': {'activity_subscription': None,
#       'blocked_by': False,
#       'blocking': None,
#       'blocking_by_list': None,
#       'followed_by': 'at://did:plc:wk7sybhegd37i7ljsltxbef6/app.bsky.graph.follow/3l7l6l226fs2z',
#       'following': 'at://did:plc:jqagnoo2ijf75flohmoqbrq4/app.bsky.graph.follow/3l7l3mi3yvw2z',
#       'known_followers': None,
#       'muted': False,
#       'muted_by_list': None,
#       'py_type': 'app.bsky.actor.defs#viewerState'},
#      'py_type': 'app.bsky.actor.defs#profileViewBasic'},
#     {'did': 'did:plc:4evsbkbuo3xj3sslot3l6qas',
#      'handle': 'mariannealq.bsky.social',
#      'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#        'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#       'chat': None,
#       'feedgens': None,
#       'labeler': None,
#       'lists': None,
#       'starter_packs': None,
#       'py_type': 'app.bsky.actor.defs#profileAssociated'},
#      'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:4evsbkbuo3xj3sslot3l6qas/bafkreid3qocdjjkhvvryxu7ud2ktt44fct26pluonua2svcxjnp6s2gsuy@jpeg',
#      'created_at': '2024-11-08T17:21:06.526Z',
#      'display_name': 'Marianne Aubin Le Quéré',
#      'labels': [],
#      'status': None,
#      'verification': None,
#      'viewer': {'activity_subscription': None,
#       'blocked_by': False,
#       'blocking': None,
#       'blocking_by_list': None,
#       'followed_by': 'at://did:plc:4evsbkbuo3xj3sslot3l6qas/app.bsky.graph.follow/3law4ujk7j72t',
#       'following': 'at://did:plc:jqagnoo2ijf75flohmoqbrq4/app.bsky.graph.follow/3law4qonola2w',
#       'known_followers': None,
#       'muted': False,
#       'muted_by_list': None,
#       'py_type': 'app.bsky.actor.defs#viewerState'},
#      'py_type': 'app.bsky.actor.defs#profileViewBasic'}],
#    'py_type': 'app.bsky.actor.defs#knownFollowers'},
#   'muted': False,
#   'muted_by_list': None,
#   'py_type': 'app.bsky.actor.defs#viewerState'},
#  'py_type': 'app.bsky.actor.defs#profileViewDetailed'}
