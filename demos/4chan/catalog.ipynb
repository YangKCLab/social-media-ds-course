# %%
import requests

# %%
api_url = "https://a.4cdn.org/{board}/catalog.json"

# %%
resp = requests.get(api_url.format(board="g"))

# %%
resp_json = resp.json()

# %%
page_1 = resp_json[0]

# %%
page_1
# Out:
# {'page': 1,
#  'threads': [{'no': 105076684,
#    'sticky': 1,
#    'closed': 1,
#    'now': '04/25/25(Fri)16:24:10',
#    'name': 'Anonymous',
#    'com': 'This board is for the discussion of technology and related topics.<br>\r\n<br>\r\nReminder that instigating OR participating in flame/brand wars will result in a ban.<br>\r\nTech support threads should be posted to <a href="https://boards.4chan.org/wsr/"><a href="//boards.4chan.org/wsr/" class="quotelink">&gt;&gt;&gt;/wsr/</a></a><br>\r\nCryptocurrency discussion belongs on <a href="https://boards.4chan.org/biz/"><a href="//boards.4chan.org/biz/" class="quotelink">&gt;&gt;&gt;/biz/</a></a><br>\r\n<br>\r\nTo use the Code tag, book-end your body of code with: [code] and [/code]<br>\r\n<br>\r\nThe /g/ Wiki: <a href="https://igwiki.lyci.de/">https://igwiki.lyci.de/</a>',
#    'filename': 'sticky btfo',
#    'ext': '.png',
#    'w': 535,
#    'h': 420,
#    'tn_w': 250,
#    'tn_h': 196,
#    'tim': 1745612650141704,
#    'time': 1745612650,
#    'md5': 'zuZHMJMYYp5WY7vM397nWQ==',
#    'fsize': 301273,
#    'resto': 0,
#    'capcode': 'mod',
#    'semantic_url': 'this-board-is-for-the-discussion-of-technology',
#    'replies': 3,
#    'images': 3,
#    'omitted_posts': 2,
#    'omitted_images': 2,
#    'last_replies': [{'no': 105076692,
#      'now': '04/25/25(Fri)16:24:40',
#      'name': 'Anonymous',
#      'filename': 'RMS',
#      'ext': '.png',
#      'w': 450,
#      'h': 399,
#      'tn_w': 125,
#      'tn_h': 110,
#      'tim': 1745612680763609,
#      'time': 1745612680,
#      'md5': 'MWh/8IxI4GKjvV4QsmJGow==',
#      'fsize': 293402,
#      'resto': 105076684,
#      'capcode': 'mod'}],
#    'last_modified': 1745612922},
#   {'no': 106471057,
#    'now': '09/03/25(Wed)05:03:31',
#    'name': 'Anonymous',
#    'com': 'What&#039;s the best distro that&#039;s:<br><span class="quote">&gt;stable</span><br><span class="quote">&gt;usable</span><br><span class="quote">&gt;has no shitty software/dependencies manager</span><br><span class="quote">&gt;has no shitty DE</span><br><br>ZorinOS without KDE?<br><br><span class="quote">&gt;inb4 w11</span><br>kys nigger',
#    'filename': 'file',
#    'ext': '.png',
#    'w': 1200,
#    'h': 675,
#    'tn_w': 250,
#    'tn_h': 140,
#    'tim': 1756890211127299,
#    'time': 1756890211,
#    'md5': 'k2pDgmJqOlnbQRxM1g1Dbg==',
#    'fsize': 865268,
#    'resto': 0,
#    'bumplimit': 0,
#    'imagelimit': 0,
#    'semantic_url': 'whats-the-best-distro-thats',
#    'replies': 48,
#    'images': 1,
#    'omitted_posts': 43,
#    'omitted_images': 1,
#    'last_replies': [{'no': 106473378,
#      'now': '09/03/25(Wed)10:57:36',
#      'name': 'Anonymous',
#      'com': '<a href="#p106471057" class="quotelink">&gt;&gt;106471057</a><br>Just install Linux from stretch and stop bitchin.',
#      'time': 1756911456,
#      'resto': 106471057},
#     {'no': 106473436,
#      'now': '09/03/25(Wed)11:04:25',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473338" class="quotelink">&gt;&gt;106473338</a><br><span class="quote">&gt;The only one that matches this description is *KRRRRASHES*</span>',
#      'time': 1756911865,
#      'resto': 106471057},
#     {'no': 106473484,
#      'now': '09/03/25(Wed)11:09:23',
#      'name': 'Anonymous',
#      'com': 'It&#039;s Mint, it&#039;s been Mint for the past 10 years',
#      'time': 1756912163,
#      'resto': 106471057},
#     {'no': 106473492,
#      'now': '09/03/25(Wed)11:09:48',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473436" class="quotelink">&gt;&gt;106473436</a><br>Are you on Debian 12 or another shitty LTS distro? KDE hasn&#039;t been unstable since 5.16.<br>Actually, scratch that. Since you&#039;re looking at ZorinOS (a distro stuck in early 2022) you probably are using outdated and broken packages.',
#      'time': 1756912188,
#      'resto': 106471057},
#     {'no': 106473503,
#      'now': '09/03/25(Wed)11:10:47',
#      'name': 'Anonymous',
#      'com': '<a href="#p106471114" class="quotelink">&gt;&gt;106471114</a><br>I like cinnamon because it&#039;s way lighter weight than GNOME or KDE, but it has a lot of the same fancy features that are easy to setup, and it&#039;s also customizable enough for my tastes. Xfce is great, it&#039;s lightweight and very flexible, but it&#039;s more minimal and requires more fiddling to get things like custom system sounds.<br>Just depends on whether you want a sane version of a &quot;modern&quot; desktop, or a more minimal, faster one.',
#      'time': 1756912247,
#      'resto': 106471057}],
#    'last_modified': 1756912247},
#   {'no': 106473300,
#    'now': '09/03/25(Wed)10:50:02',
#    'name': 'Anonymous',
#    'com': '<span class="quote">&gt;Creates his own minecraft clone (twice)</span><br><span class="quote">&gt;his own operating system</span><br><span class="quote">&gt;his own display manager library</span><br><span class="quote">&gt;his own window manager</span><br><span class="quote">&gt;his own programming language</span><br><span class="quote">&gt;his own calculator OS</span><br><span class="quote">&gt;But is quickly forgotten after taking the fatal beef with Stallman</span><br>How is Stallman so powerful? Drew has coded more than him and created more and he lost so quickly that it is not even funny. It was not even a tough battle for Stallman ...',
#    'filename': '1756910993153',
#    'ext': '.png',
#    'w': 296,
#    'h': 296,
#    'tn_w': 250,
#    'tn_h': 250,
#    'tim': 1756911002319171,
#    'time': 1756911002,
#    'md5': 'CJCBKI42OzziaUz5eYxPFg==',
#    'fsize': 197341,
#    'resto': 0,
#    'bumplimit': 0,
#    'imagelimit': 0,
#    'semantic_url': 'creates-his-own-minecraft-clone-twice',
#    'replies': 9,
#    'images': 2,
#    'omitted_posts': 4,
#    'omitted_images': 1,
#    'last_replies': [{'no': 106473463,
#      'now': '09/03/25(Wed)11:07:11',
#      'name': 'Anonymous',
#      'filename': 'child rapist',
#      'ext': '.webm',
#      'w': 864,
#      'h': 1168,
#      'tn_w': 92,
#      'tn_h': 125,
#      'tim': 1756912031087979,
#      'time': 1756912031,
#      'md5': 'Hyps5LI7AZpYCAXfvBCqBg==',
#      'fsize': 465306,
#      'resto': 106473300},
#     {'no': 106473474,
#      'now': '09/03/25(Wed)11:08:21',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473396" class="quotelink">&gt;&gt;106473396</a><br>Stallman is an acknowledged pedo and fairly open about it, while Drew is a closeted one, far more dangerous and unpredictable.',
#      'time': 1756912101,
#      'resto': 106473300},
#     {'no': 106473487,
#      'now': '09/03/25(Wed)11:09:33',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473474" class="quotelink">&gt;&gt;106473474</a><br><span class="quote">&gt;Stallman is an acknowledged pedo</span><br>wrong',
#      'time': 1756912173,
#      'resto': 106473300},
#     {'no': 106473496,
#      'now': '09/03/25(Wed)11:10:13',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473300" class="quotelink">&gt;&gt;106473300</a><br><span class="quote">&gt;born in 1993</span><br><span class="quote">&gt;alr bald</span><br>lolle<br>manlet genes<br><br>im born in 89 and i look way younger than him<br>and i drink, smoke and do drugs<br>worked for 10 years in construction<br><br>he fucking looks 40',
#      'time': 1756912213,
#      'resto': 106473300},
#     {'no': 106473508,
#      'now': '09/03/25(Wed)11:11:34',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473496" class="quotelink">&gt;&gt;106473496</a><br>dumb retard',
#      'time': 1756912294,
#      'resto': 106473300}],
#    'last_modified': 1756912294},
#   {'no': 106472582,
#    'now': '09/03/25(Wed)09:26:13',
#    'name': 'Anonymous',
#    'com': 'A lot of /g/entoomen buy old hardware but how many of you still use your old hardware after many years? <br><br>I still have my X200t I bought in 2013 and still use it sometimes, mostly to play old vidya or as a travel laptop because I can&#039;t travel with just a phone.',
#    'filename': 'that feel when x200 thinkpad',
#    'ext': '.png',
#    'w': 600,
#    'h': 723,
#    'tn_w': 207,
#    'tn_h': 250,
#    'tim': 1756905973443591,
#    'time': 1756905973,
#    'md5': '0yB4EkF0mIQr8/oyFGu9Gg==',
#    'fsize': 759780,
#    'resto': 0,
#    'bumplimit': 0,
#    'imagelimit': 0,
#    'semantic_url': 'a-lot-of-gentoomen-buy-old-hardware-but-how-many',
#    'replies': 3,
#    'images': 1,
#    'last_replies': [{'no': 106472741,
#      'now': '09/03/25(Wed)09:46:47',
#      'name': 'Anonymous',
#      'com': '2009 as daily drive',
#      'time': 1756907207,
#      'resto': 106472582},
#     {'no': 106472899,
#      'now': '09/03/25(Wed)10:07:43',
#      'name': 'Anonymous',
#      'com': '<a href="#p106472582" class="quotelink">&gt;&gt;106472582</a><br><span class="quote">&gt;a travel laptop because I can&#039;t travel with just a phone</span><br>Why are /g/aymen like this?',
#      'time': 1756908463,
#      'resto': 106472582},
#     {'no': 106473507,
#      'now': '09/03/25(Wed)11:11:31',
#      'name': 'Anonymous',
#      'com': '<a href="#p106472582" class="quotelink">&gt;&gt;106472582</a><br>For me its a Panasonic CF29 running Windows XP and an Advantech P37B running Windows CE 5.0',
#      'filename': '1745841126575608',
#      'ext': '.jpg',
#      'w': 2975,
#      'h': 3675,
#      'tn_w': 101,
#      'tn_h': 125,
#      'tim': 1756912291252996,
#      'time': 1756912291,
#      'md5': 'sliMUzwcmP3Z5kJLE8Nb5g==',
#      'fsize': 978353,
#      'resto': 106472582}],
#    'last_modified': 1756912291},
#   {'no': 106471022,
#    'now': '09/03/25(Wed)04:51:23',
#    'name': 'Anonymous',
#    'sub': '/DE3/ - DALL-E 3/Cloud AI Image Generation General',
#    'com': 'Previous Thread: <a href="/g/thread/106429338#p106429338" class="quotelink">&gt;&gt;106429338</a><br><br><span class="quote">&gt;Links:</span><br><span class="quote">&gt;DALL-E 3</span><br>https://www.bing.com/images/create<br>https://designer.microsoft.com/imag<wbr>e-creator<br><span class="quote">&gt;4o</span><br>https://chatgpt.com/<br>https://sora.chatgpt.com<br>https://copilot.microsoft.com/<br><span class="quote">&gt;Imagen 3</span><br>https://labs.google/fx/tools/image-<wbr>fx<br><span class="quote">&gt;Imagen 4</span><br>https://gemini.google.com/app<br>https://labs.google/fx/tools/whisk<br>https://aistudio.google.com/prompts<wbr>/new_image (it also supports imagen3)<br><span class="quote">&gt;Midjourney [PAID]</span><br>https://www.midjourney.com/home<br><span class="quote">&gt;NovelAI [PAID]</span><br>https://novelai.net/image<br><span class="quote">&gt;Perchance</span><br>https://perchance.org/ai-text-to-im<wbr>age-generator<br><br><span class="quote">&gt;Download links for latest Bing and Designer Slop scripts:</span><br>https://pastebin.com/raw/bk33MxxG<br><br><span class="quote">&gt;Instructions and download for BIC EDIT script:</span><br>https://rentry.org/bicedit<br><br><span class="quote">&gt;Prompt Generator</span><br>https://tipseason.com/dalle-prompt-<wbr>generator<br><br><span class="quote">&gt;DALL-E 3 image generation guide</span><br>https://files.catbox.moe/o4yihf.png<wbr><br>https://files.catbox.moe/320rm1.png<wbr><br>https://files.catbox.moe/8gge6o.png<wbr><br>https://files.catbox.moe/dcokjf.png<wbr><br><br><span class="quote">&gt;Perchance generator list</span><br>https://pastebin.com/XRGqaW4W<br><br><span class="quote">&gt;Related Boards</span><br><a href="//boards.4chan.org/v/catalog#s=dall-e" class="quotelink">&gt;&gt;&gt;/v/dall-e</a><br><a href="//boards.4chan.org/co/catalog#s=dall-e" class="quotelink">&gt;&gt;&gt;/co/dall-e</a><br><a href="//boards.4chan.org/trash/catalog#s=aibf" class="quotelink">&gt;&gt;&gt;/trash/aibf</a><br><a href="//boards.4chan.org/aco/catalog#s=dall" class="quotelink">&gt;&gt;&gt;/aco/dall</a><br><a href="//boards.4chan.org/tg/catalog#s=slop" class="quotelink">&gt;&gt;&gt;/tg/slop</a>',
#    'filename': 'Whisk_82b7d39483',
#    'ext': '.jpg',
#    'w': 1024,
#    'h': 1024,
#    'tn_w': 250,
#    'tn_h': 250,
#    'tim': 1756889483909999,
#    'time': 1756889483,
#    'md5': 'z7f4Hzyl908Dt+mCsthgZg==',
#    'fsize': 713883,
#    'resto': 0,
#    'bumplimit': 0,
#    'imagelimit': 0,
#    'semantic_url': 'de3-dalle-3cloud-ai-image-generation-general',
#    'replies': 23,
#    'images': 22,
#    'omitted_posts': 18,
#    'omitted_images': 18,
#    'last_replies': [{'no': 106472692,
#      'now': '09/03/25(Wed)09:40:02',
#      'name': 'Anonymous',
#      'com': 'It looks like /co/ died again.',
#      'time': 1756906802,
#      'resto': 106471022,
#      'filedeleted': 1},
#     {'no': 106472720,
#      'now': '09/03/25(Wed)09:43:19',
#      'name': 'Anonymous',
#      'com': 'BTW, Nano Banana is indeed convenient to fix stuff.',
#      'filename': 'Generated Image September 03, 2025 - 3_42PM',
#      'ext': '.jpg',
#      'w': 1248,
#      'h': 832,
#      'tn_w': 125,
#      'tn_h': 83,
#      'tim': 1756906999271296,
#      'time': 1756906999,
#      'md5': 'NoUCx0ET+JI+kvXZgSD7Mw==',
#      'fsize': 382296,
#      'resto': 106471022},
#     {'no': 106473294,
#      'now': '09/03/25(Wed)10:49:23',
#      'name': 'Anonymous',
#      'com': '<a href="#p106472692" class="quotelink">&gt;&gt;106472692</a><br><a href="#p106472720" class="quotelink">&gt;&gt;106472720</a><br>Life support for sloppers these days, even with amazing tools like this coming out. Sad times.',
#      'filename': 'M420',
#      'ext': '.jpg',
#      'w': 1024,
#      'h': 1024,
#      'tn_w': 125,
#      'tn_h': 125,
#      'tim': 1756910963853556,
#      'time': 1756910963,
#      'md5': '083U2vo8MPeoNbrbIin4wQ==',
#      'fsize': 600542,
#      'resto': 106471022},
#     {'no': 106473353,
#      'now': '09/03/25(Wed)10:54:52',
#      'name': 'Anonymous',
#      'filename': '_3c4fcc36-1b79-44af-95b3-c204c9d03cd4',
#      'ext': '.jpg',
#      'w': 1792,
#      'h': 1024,
#      'tn_w': 125,
#      'tn_h': 71,
#      'tim': 1756911292959851,
#      'time': 1756911292,
#      'md5': 'aKtV0GdutZ+aXE6Jo9zSaQ==',
#      'fsize': 483089,
#      'resto': 106471022},
#     {'no': 106473505,
#      'now': '09/03/25(Wed)11:11:06',
#      'name': 'Anonymous',
#      'filename': '20250903_1008_Misty&#039;s Tarot Haven_simple_compose_01k481vfnaeqztzp4qtcc0q22d',
#      'ext': '.png',
#      'w': 1536,
#      'h': 1024,
#      'tn_w': 125,
#      'tn_h': 83,
#      'tim': 1756912266815247,
#      'time': 1756912266,
#      'md5': 'oA73EC8EB6u5j6rIhnf0ag==',
#      'fsize': 2601340,
#      'resto': 106471022}],
#    'last_modified': 1756912266},
#   {'no': 106468416,
#    'now': '09/02/25(Tue)20:14:03',
#    'name': 'Anonymous',
#    'sub': 'People Are Furious That OpenAI Is Reporting ChatGPT Conversations to Law Enforcement',
#    'com': '<span class="quote">&gt;Earlier this week, buried in the middle of a lengthy blog post addressing ChatGPT&#039;s propensity for severe mental health harms, OpenAI admitted that it&#039;s scanning users&#039; conversations and reporting to police any interactions that a human reviewer deems sufficiently threatening.</span><br><br><span class="quote">&gt;&quot;When we detect users who are planning to harm others, we route their conversations to specialized pipelines where they are reviewed by a small team trained on our usage policies and who are authorized to take action, including banning accounts,&quot; it wrote. &quot;If human reviewers determine that a case involves an imminent threat of serious physical harm to others, we may refer it to law enforcement.&quot;</span><br><br>https://futurism.com/people-furious<wbr>-openai-reporting-police',
#    'filename': 'ass',
#    'ext': '.jpg',
#    'w': 979,
#    'h': 1211,
#    'tn_w': 202,
#    'tn_h': 249,
#    'tim': 1756858443190243,
#    'time': 1756858443,
#    'md5': 'DVJMu/oy41bxA8ZFwqQj1A==',
#    'fsize': 139449,
#    'resto': 0,
#    'bumplimit': 0,
#    'imagelimit': 0,
#    'semantic_url': 'people-are-furious-that-openai-is-reporting',
#    'replies': 58,
#    'images': 10,
#    'omitted_posts': 53,
#    'omitted_images': 10,
#    'last_replies': [{'no': 106472759,
#      'now': '09/03/25(Wed)09:49:36',
#      'name': 'Anonymous',
#      'com': '<a href="#p106469980" class="quotelink">&gt;&gt;106469980</a><br><span class="quote">&gt;latest</span><br>when did you become conscious? jw',
#      'time': 1756907376,
#      'resto': 106468416},
#     {'no': 106472774,
#      'now': '09/03/25(Wed)09:52:05',
#      'name': 'Anonymous',
#      'com': '<a href="#p106472731" class="quotelink">&gt;&gt;106472731</a><br>https://www.douyin.com/user/MS4wLjA<wbr>BAAAAP7Z5kBdUE464Tq8LwnoZKmK4FyLu3f<wbr>gBwteBXkf_n2k4F4HZ2Dy0WssiGPxOK49W<br>https://www.baike.com/wikiid/741737<wbr>8604868272154',
#      'time': 1756907525,
#      'resto': 106468416},
#     {'no': 106472803,
#      'now': '09/03/25(Wed)09:56:00',
#      'name': 'Anonymous',
#      'com': '<a href="#p106468416" class="quotelink">&gt;&gt;106468416</a><br>i would bery my dick so deep whoever pulls it out can be crowned king arthur',
#      'time': 1756907760,
#      'resto': 106468416},
#     {'no': 106473479,
#      'now': '09/03/25(Wed)11:08:58',
#      'name': 'Anonymous',
#      'com': '<a href="#p106468416" class="quotelink">&gt;&gt;106468416</a><br>I will now proceed to spam fuck jews and that Hitler did nothing wrong everyday',
#      'time': 1756912138,
#      'resto': 106468416},
#     {'no': 106473504,
#      'now': '09/03/25(Wed)11:10:59',
#      'name': 'Anonymous',
#      'com': '<a href="#p106468416" class="quotelink">&gt;&gt;106468416</a><br>If you&#039;re dumb enough to use AI you deserve to be fucked into the dirt and abused like the slave that you chose to be.',
#      'time': 1756912259,
#      'resto': 106468416}],
#    'last_modified': 1756912259},
#   {'no': 106465224,
#    'now': '09/02/25(Tue)14:18:50',
#    'name': 'Anonymous',
#    'com': 'X3D chips are ticking time bombs. Fuck AMD.',
#    'filename': '_20250902_234744',
#    'ext': '.jpg',
#    'w': 1440,
#    'h': 1851,
#    'tn_w': 194,
#    'tn_h': 250,
#    'tim': 1756837130805760,
#    'time': 1756837130,
#    'md5': '0Hi5qUT9t/F2s5NcF1RugA==',
#    'fsize': 439453,
#    'resto': 0,
#    'bumplimit': 0,
#    'imagelimit': 0,
#    'semantic_url': 'x3d-chips-are-ticking-time-bombs-fuck-amd',
#    'replies': 100,
#    'images': 13,
#    'omitted_posts': 95,
#    'omitted_images': 13,
#    'last_replies': [{'no': 106473411,
#      'now': '09/03/25(Wed)11:00:39',
#      'name': 'Anonymous',
#      'com': '<a href="#p106466575" class="quotelink">&gt;&gt;106466575</a><br>I&#039;m still using my $78 asrock b450',
#      'time': 1756911639,
#      'resto': 106465224},
#     {'no': 106473420,
#      'now': '09/03/25(Wed)11:02:53',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473201" class="quotelink">&gt;&gt;106473201</a><br>10GBe<br><br><a href="#p106473232" class="quotelink">&gt;&gt;106473232</a><br><span class="quote">&gt;moving goalposts</span><br>It&#039;s called having expectations.<br>Everybody literally celebrated the death of consumer HEDT because &quot;muh desktop lanes&quot; but suddenly it&#039;s needy to want more than 2 useful pcie slots, or to have a 15+ year old ethernet standard.',
#      'time': 1756911773,
#      'resto': 106465224},
#     {'no': 106473460,
#      'now': '09/03/25(Wed)11:07:03',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473420" class="quotelink">&gt;&gt;106473420</a><br>Then get a X870E board that has dual 10GbE? <br>I don&#039;t need it since I use a dual port 25GbE SFP+ NIC.',
#      'time': 1756912023,
#      'resto': 106465224},
#     {'no': 106473476,
#      'now': '09/03/25(Wed)11:08:31',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473420" class="quotelink">&gt;&gt;106473420</a><br><span class="quote">&gt;&gt;or to have a 15+ year old ethernet standard.</span><br><span class="quote">&gt;5GBASE-T</span><br><span class="quote">&gt;15+ years old</span><br><span class="quote">&gt;when the standard itself is only 9 years old</span>',
#      'time': 1756912111,
#      'resto': 106465224},
#     {'no': 106473502,
#      'now': '09/03/25(Wed)11:10:46',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473460" class="quotelink">&gt;&gt;106473460</a><br>post switch <br><br><a href="#p106473476" class="quotelink">&gt;&gt;106473476</a><br>10GbE is older than 5GbE<br>It&#039;s actually 19 years old as a standard.<br>You&#039;re honestly being played if they are giving you 5gbe',
#      'time': 1756912246,
#      'resto': 106465224}],
#    'last_modified': 1756912246},
#   {'no': 106467834,
#    'now': '09/02/25(Tue)18:58:55',
#    'name': 'Anonymous',
#    'sub': '/adt/ - Anime Diffusion Thread #18',
#    'com': '<span class="quote">&gt;UIs to generate anime</span><br>    ComfyUI: https://github.com/comfyanonymous/C<wbr>omfyUI<br>    SwarmUI: https://github.com/mcmonkeyprojects<wbr>/SwarmUI<br>    re/Forge/Classic: https://rentry.org/ldg-lazy-getting<wbr>-started-guide#reforgeclassic<br>    SD.Next: https://github.com/vladmandic/sdnex<wbr>t<br>    Wan2GP: https://github.com/deepbeepmeep/Wan<wbr>2GP<br>    AniStudio(status: two more weeks): https://github.com/FizzleDorf/AniSt<wbr>udio<br>    InvokeAI: https://www.invoke.com/<br><br>    &gt;How to Generating Anime Images<br>    https://rentry.org/comfyui_guide_1g<wbr>irl<br>    https://tagexplorer.github.io<br><br>    &gt;Generating Anime Videos<br>    Guide:<br>    https://rentry.org/wan22ldgguide<br><br>    &gt;Anime Checkpoints, LoRAs, Upscalers, &amp; Workflows<br>    https://civitai.com<br>    https://civitaiarchive.com<br>    https://tensor.art<br>    https://openmodeldb.info<br>    https://openart.ai/workflows<br>    https://www.seaart.ai<br>    https://www.liblib.art/<br><br>    &gt;Anime Misc<br>    Local Model Meta: https://rentry.org/localmodelsmeta<br>    Share Metadata: https://catbox.moe | https://litterbox.catbox.moe<br>    Img2Prompt: https://huggingface.co/spaces/fancy<wbr>feast/joy-caption-beta-one<br>    Samplers: https://stable-diffusion-art.com/sa<wbr>mplers<br>    Txt2Img Plugin: https://github.com/Acly/krita-ai-di<wbr>ffusion<br>    Online metadata viewer SD/NovelAI: https://spell.novelai.dev<br><br>    &gt;Neighbours<br>    https://rentry.org/ldg-lazy-getting<wbr>-started-guide#rentry-from-other-bo<wbr>ards<br>    <a href="//boards.4chan.org/aco/catalog#s=csdg" class="quotelink">&gt;&gt;&gt;/aco/csdg</a><br>    <a href="//boards.4chan.org/b/catalog#s=degen" class="quotelink">&gt;&gt;&gt;/b/degen</a><br>    <a href="//boards.4chan.org/b/catalog#s=realistic+parody" class="quotelink">&gt;&gt;&gt;/b/realistic+parody</a><br>    <a href="//boards.4chan.org/gif/catalog#s=vdg" class="quotelink">&gt;&gt;&gt;/gif/vdg</a><br>    <a href="//boards.4chan.org/d/catalog#s=ddg" class="quotelink">&gt;&gt;&gt;/d/ddg</a><br>    <a href="//boards.4chan.org/e/catalog#s=edg" class="quotelink">&gt;&gt;&gt;/e/edg</a><br>    <a href="//boards.4chan.org/h/catalog#s=hdg" class="quotelink">&gt;&gt;&gt;/h/hdg</a><br>    <a href="//boards.4chan.org/trash/catalog#s=slop" class="quotelink">&gt;&gt;&gt;/trash/slop</a><br>    <a href="//boards.4chan.org/vt/catalog#s=vtai" class="quotelink">&gt;&gt;&gt;/vt/vtai</a><br>    <a href="//boards.4chan.org/u/catalog#s=udg" class="quotelink">&gt;&gt;&gt;/u/udg</a><br>    <a href="//boards.4chan.org/r9k/catalog#s=aiwg%2F" class="quotelink">&gt;&gt;&gt;/r9k/aiwg/</a><br>    &gt;Local Text&amp;Image<br>    <a href="//boards.4chan.org/g/catalog#s=lmg" class="quotelink">&gt;&gt;&gt;/g/lmg</a><br>    <a href="//boards.4chan.org/g/catalog#s=ldg" class="quotelink">&gt;&gt;&gt;/g/ldg</a><br>    <a href="//boards.4chan.org/vp/catalog#s=napt" class="quotelink">&gt;&gt;&gt;/vp/napt</a><br>    &gt;Cloud Text&amp;Image<br>    <a href="//boards.4chan.org/g/catalog#s=aicg" class="quotelink">&gt;&gt;&gt;/g/aicg</a><br>    <a href="//boards.4chan.org/g/catalog#s=sdg%2F" class="quotelink">&gt;&gt;&gt;/g/sdg/</a><br><br>    Prev: <a href="/g/thread/106449828#p106449828" class="quotelink">&gt;&gt;106449828</a>',
#    'filename': '18 collage',
#    'ext': '.jpg',
#    'w': 4096,
#    'h': 4096,
#    'tn_w': 250,
#    'tn_h': 250,
#    'tim': 1756853935194230,
#    'time': 1756853935,
#    'md5': '3HjLsem0xvKyaPAbr3nwuw==',
#    'fsize': 3222756,
#    'resto': 0,
#    'bumplimit': 0,
#    'imagelimit': 0,
#    'semantic_url': 'adt-anime-diffusion-thread-18',
#    'replies': 198,
#    'images': 74,
#    'omitted_posts': 193,
#    'omitted_images': 72,
#    'last_replies': [{'no': 106473387,
#      'now': '09/03/25(Wed)10:58:23',
#      'name': 'Anonymous',
#      'com': '<a href="#p106471721" class="quotelink">&gt;&gt;106471721</a><br>.',
#      'filename': 'no maes',
#      'ext': '.jpg',
#      'w': 1792,
#      'h': 2384,
#      'tn_w': 93,
#      'tn_h': 125,
#      'tim': 1756911503879601,
#      'time': 1756911503,
#      'md5': 'cuJq176r0fW72YwdNj09Lg==',
#      'fsize': 1410425,
#      'resto': 106467834},
#     {'no': 106473409,
#      'now': '09/03/25(Wed)11:00:37',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473241" class="quotelink">&gt;&gt;106473241</a><br>Don&#039;t know the character, what is the story between her, the eye and the lime?',
#      'time': 1756911637,
#      'resto': 106467834},
#     {'no': 106473424,
#      'now': '09/03/25(Wed)11:03:03',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473040" class="quotelink">&gt;&gt;106473040</a><br>Coco ilustrious noob? nice! thanks!',
#      'time': 1756911783,
#      'resto': 106467834},
#     {'no': 106473454,
#      'now': '09/03/25(Wed)11:06:24',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473409" class="quotelink">&gt;&gt;106473409</a><br>there&#039;s not any real relationship to slime, was just trying to gen something like a slime trap in a dungeon',
#      'time': 1756911984,
#      'resto': 106467834},
#     {'no': 106473501,
#      'now': '09/03/25(Wed)11:10:42',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473409" class="quotelink">&gt;&gt;106473409</a><br>her eye lets her read the hearts of others, leading to funny hypothetical situations where she gets flustered by lewd thoughts',
#      'filename': '00050-1625984412',
#      'ext': '.png',
#      'w': 1024,
#      'h': 1024,
#      'tn_w': 125,
#      'tn_h': 125,
#      'tim': 1756912242707396,
#      'time': 1756912242,
#      'md5': 'BBVF11wMtEDcFNEDEAt85w==',
#      'fsize': 1304973,
#      'resto': 106467834}],
#    'last_modified': 1756912242},
#   {'no': 106440500,
#    'now': '08/31/25(Sun)03:23:23',
#    'name': 'Anonymous',
#    'sub': '/wdg/ - Web Development General',
#    'com': 'King of front-end edition.<br><br><span class="quote">&gt;Free beginner resources to get started with HTML, CSS and JS</span><br>https://developer.mozilla.org/en-US<wbr>/docs/Learn - MDN is your friend for web dev fundamentals<br>https://web.dev/learn/ - Guides by Google, you can also learn concepts like Accessibility, Responsive Design etc<br>https://eloquentjavascript.net/Eloq<wbr>uent_JavaScript.pdf - A modern introduction to JavaScript<br>https://javascript.info/ - Quite a good JS tutorial<br>https://flukeout.github.io/ - Learn CSS selectors in no time<br>https://flexboxfroggy.com/ and https://cssgridgarden.com/ - Learn flex and grid in CSS<br><br><span class="quote">&gt;Resources for backend languages</span><br>https://nodejs.org/en/learn/getting<wbr>-started/introduction-to-nodejs - An intro to Node.js<br>https://www.phptutorial.net - A PHP tutorial<br>https://dev.java/learn/ - A Java tutorial<br>https://rentry.org/htbby - Links for Python and Go<br>https://quii.gitbook.io/learn-go-wi<wbr>th-tests - Learn Go with Tests<br><br><span class="quote">&gt;Resources for miscellaneous areas</span><br>https://github.com/bradtraversy/des<wbr>ign-resources-for-developers - List of design resources<br>https://www.digitalocean.com/commun<wbr>ity/tutorials - Usually the best guides for everything server related<br><br><span class="quote">&gt;Need help? Create an example and post the link</span><br>https://jsfiddle.net - if you need help with HTML/CSS/JS<br>https://3v4l.org - if you need help with PHP/HackLang<br>https://codesandbox.io - if you need help with React/Angular/Vue<br><br>/wdg/ may or may not welcome app development discussion. You can post and see what the response is.<br>Some app technologies of course have overlap with web dev, like React Native, Electron, and Flutter.<br><br>We have our own website: https://wdg-one.github.io<br><br>Submit your project progress updates using this format in your posts, the scraper will pick it up:<br><br>:: my-project-title ::<br>dev:: anon<br>tools:: PHP, MySQL, etc.<br>link:: https://my.website.com<br>repo:: https://github.com/user/repo<br>progress:: Lorem ipsum dolor sit amet<br><br>Previous: <a href="/g/thread/106399363#p106399363" class="quotelink">&gt;&gt;106399363</a>',
#    'filename': 'wordmark_light',
#    'ext': '.png',
#    'w': 1200,
#    'h': 361,
#    'tn_w': 250,
#    'tn_h': 75,
#    'tim': 1756625003615334,
#    'time': 1756625003,
#    'md5': 'MxoM3gFfdzC02C0JQwWEHQ==',
#    'fsize': 51215,
#    'resto': 0,
#    'bumplimit': 0,
#    'imagelimit': 0,
#    'semantic_url': 'wdg-web-development-general',
#    'replies': 127,
#    'images': 20,
#    'omitted_posts': 122,
#    'omitted_images': 18,
#    'last_replies': [{'no': 106472865,
#      'now': '09/03/25(Wed)10:04:53',
#      'name': 'Anonymous',
#      'com': 'I hate promises so much',
#      'time': 1756908293,
#      'resto': 106440500},
#     {'no': 106473093,
#      'now': '09/03/25(Wed)10:28:45',
#      'name': 'Anonymous',
#      'com': '<a href="#p106472865" class="quotelink">&gt;&gt;106472865</a><br>I can promise you I don&#039;t callback either.',
#      'time': 1756909725,
#      'resto': 106440500},
#     {'no': 106473388,
#      'now': '09/03/25(Wed)10:58:26',
#      'name': 'Anonymous',
#      'com': '<a href="#p106472865" class="quotelink">&gt;&gt;106472865</a><br>They&#039;re pretty simple to use in my experience',
#      'time': 1756911506,
#      'resto': 106440500},
#     {'no': 106473432,
#      'now': '09/03/25(Wed)11:04:05',
#      'name': 'Anonymous',
#      'com': '<a href="#p106440500" class="quotelink">&gt;&gt;106440500</a><br>My home web server is a php file that dynamically generates the page content and menu from a json file',
#      'filename': '1747218009759677',
#      'ext': '.png',
#      'w': 500,
#      'h': 540,
#      'tn_w': 115,
#      'tn_h': 125,
#      'tim': 1756911845893539,
#      'time': 1756911845,
#      'md5': '6pFT1IhAVNvoUodydMlmZw==',
#      'fsize': 256823,
#      'resto': 106440500},
#     {'no': 106473500,
#      'now': '09/03/25(Wed)11:10:42',
#      'name': 'Anonymous',
#      'com': '<a href="/g/thread/106399363#p106419365" class="quotelink">&gt;&gt;106419365</a><br>Finally fixed it.<br>I didn&#039;t have to re-implement zlib deflate in the browser. It was much fucking png filter reconstruction failing edge cases all along. And it only took rewriting my png decoder to handle byte streams in full color to find out.<br>Have some glitch art.',
#      'filename': 'glitchart',
#      'ext': '.png',
#      'w': 960,
#      'h': 2388,
#      'tn_w': 50,
#      'tn_h': 125,
#      'tim': 1756912242351686,
#      'time': 1756912242,
#      'md5': '1nriviqCkIVAUtbe/DuKOA==',
#      'fsize': 3509050,
#      'resto': 106440500}],
#    'last_modified': 1756912242},
#   {'no': 106473028,
#    'now': '09/03/25(Wed)10:21:49',
#    'name': 'Anonymous',
#    'com': 'Hey anons, quick question<br>what are the differences between .com, . net, and, .org',
#    'filename': 'Screenshot 2025-09-03 at 16-21-06 image001-17.jpg (JPEG Image 297 × 198 pixels)',
#    'ext': '.png',
#    'w': 371,
#    'h': 247,
#    'tn_w': 250,
#    'tn_h': 166,
#    'tim': 1756909309425959,
#    'time': 1756909309,
#    'md5': 'AkHBLwF2JYW2v1ZLzVCW3Q==',
#    'fsize': 119032,
#    'resto': 0,
#    'bumplimit': 0,
#    'imagelimit': 0,
#    'semantic_url': 'hey-anons-quick-question',
#    'replies': 10,
#    'images': 0,
#    'omitted_posts': 5,
#    'omitted_images': 0,
#    'last_replies': [{'no': 106473315,
#      'now': '09/03/25(Wed)10:51:18',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473028" class="quotelink">&gt;&gt;106473028</a><br>why don&#039;t you just ask the chatgpt, zoomie?',
#      'time': 1756911078,
#      'resto': 106473028},
#     {'no': 106473362,
#      'now': '09/03/25(Wed)10:55:50',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473028" class="quotelink">&gt;&gt;106473028</a><br>Domain names were meant to label specific websites  (.net for network providers, .org for organizations and .com for commercial sites)',
#      'time': 1756911350,
#      'resto': 106473028},
#     {'no': 106473437,
#      'now': '09/03/25(Wed)11:04:28',
#      'name': 'Anonymous',
#      'com': '.&#039;-&#039;',
#      'time': 1756911868,
#      'resto': 106473028},
#     {'no': 106473472,
#      'now': '09/03/25(Wed)11:08:18',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473362" class="quotelink">&gt;&gt;106473362</a><br>Is 4chan a organization?',
#      'time': 1756912098,
#      'resto': 106473028},
#     {'no': 106473499,
#      'now': '09/03/25(Wed)11:10:35',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473028" class="quotelink">&gt;&gt;106473028</a><br>some of them hold more authority than others in regards to search engine ranking results',
#      'time': 1756912235,
#      'resto': 106473028}],
#    'last_modified': 1756912235},
#   {'no': 106466020,
#    'now': '09/02/25(Tue)15:40:32',
#    'name': 'Anonymous',
#    'com': 'JUST',
#    'filename': 'file',
#    'ext': '.png',
#    'w': 2880,
#    'h': 1800,
#    'tn_w': 250,
#    'tn_h': 156,
#    'tim': 1756842032779284,
#    'time': 1756842032,
#    'md5': '5cjWg3g2h0kHWc9wNF/mpw==',
#    'fsize': 2686844,
#    'resto': 0,
#    'bumplimit': 0,
#    'imagelimit': 0,
#    'semantic_url': 'just',
#    'replies': 48,
#    'images': 8,
#    'omitted_posts': 43,
#    'omitted_images': 8,
#    'last_replies': [{'no': 106473347,
#      'now': '09/03/25(Wed)10:53:43',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473257" class="quotelink">&gt;&gt;106473257</a><br><span class="quote">&gt;still parroting decades old joke that hasn&#039;t been relevant for a long time</span><br>GNOME shills are pathetic',
#      'time': 1756911223,
#      'resto': 106466020},
#     {'no': 106473408,
#      'now': '09/03/25(Wed)11:00:36',
#      'name': 'Anonymous',
#      'com': '<a href="#p106466020" class="quotelink">&gt;&gt;106466020</a><br><span class="quote">&gt;cuckbar is still there</span><br>some things never change',
#      'time': 1756911636,
#      'resto': 106466020},
#     {'no': 106473415,
#      'now': '09/03/25(Wed)11:01:37',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473066" class="quotelink">&gt;&gt;106473066</a><br>no shit, gnome is a literal mac ripoff',
#      'time': 1756911697,
#      'resto': 106466020},
#     {'no': 106473490,
#      'now': '09/03/25(Wed)11:09:45',
#      'name': 'Anonymous',
#      'com': '<a href="#p106466020" class="quotelink">&gt;&gt;106466020</a><br>STOP ROUNDING EDGES<br>FUCK',
#      'time': 1756912185,
#      'resto': 106466020},
#     {'no': 106473498,
#      'now': '09/03/25(Wed)11:10:18',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473490" class="quotelink">&gt;&gt;106473490</a><br>no',
#      'time': 1756912218,
#      'resto': 106466020}],
#    'last_modified': 1756912218},
#   {'no': 106469492,
#    'now': '09/02/25(Tue)23:19:19',
#    'name': 'Anonymous',
#    'sub': '/ldg/ - Local Diffusion General',
#    'com': 'Discussion of Free and Open Source Text-to-Image/Video Models and UI<br><br>Prev: <a href="/g/thread/106464276#p106464276" class="quotelink">&gt;&gt;106464276</a><br><br>https://rentry.org/ldg-lazy-getting<wbr>-started-guide<br><br><span class="quote">&gt;UI</span><br>ComfyUI: https://github.com/comfyanonymous/C<wbr>omfyUI<br>SwarmUI: https://github.com/mcmonkeyprojects<wbr>/SwarmUI<br>re/Forge/Classic: https://rentry.org/ldg-lazy-getting<wbr>-started-guide#reforgeclassic<br>Chromaforge: https://github.com/maybleMyers/chro<wbr>maforge<br>SD.Next: https://github.com/vladmandic/sdnex<wbr>t<br>Wan2GP: https://github.com/deepbeepmeep/Wan<wbr>2GP<br><br><span class="quote">&gt;Checkpoints, LoRAs, Upscalers, &amp; Workflows</span><br>https://civitai.com<br>https://civitaiarchive.com/<br>https://tensor.art<br>https://openmodeldb.info<br>https://openart.ai/workflows<br><br><span class="quote">&gt;Tuning</span><br>https://github.com/spacepxl/demysti<wbr>fying-sd-finetuning<br>https://github.com/Nerogar/OneTrain<wbr>er<br>https://github.com/kohya-ss/sd-scri<wbr>pts/tree/sd3<br>https://github.com/derrian-distro/L<wbr>oRA_Easy_Training_Scripts<br>https://github.com/tdrussell/diffus<wbr>ion-pipe<br><br><span class="quote">&gt;WanX</span><br>https://rentry.org/wan22ldgguide<br>https://github.com/Wan-Video<br>https://alidocs.dingtalk.com/i/node<wbr>s/EpGBa2Lm8aZxe5myC99MelA2WgN7R35y<br><br><span class="quote">&gt;Chroma</span><br>https://huggingface.co/lodestones/C<wbr>hroma1-Base<br>Training: https://rentry.org/mvu52t46<br><br><span class="quote">&gt;Illustrious</span><br>1girl and Beyond: https://rentry.org/comfyui_guide_1g<wbr>irl<br>Tag Explorer: https://tagexplorer.github.io/<br><br><span class="quote">&gt;Misc</span><br>Local Model Meta: https://rentry.org/localmodelsmeta<br>Share Metadata: https://catbox.moe | https://litterbox.catbox.moe/<br>GPU Benchmarks: https://chimolog.co/bto-gpu-stable-<wbr>diffusion-specs/<br>Img2Prompt: https://huggingface.co/spaces/fancy<wbr>feast/joy-caption-beta-one<br>Samplers: https://stable-diffusion-art.com/sa<wbr>mplers/<br>Txt2Img Plugin: https://github.com/Acly/krita-ai-di<wbr>ffusion<br>Archive: https://rentry.org/sdg-link<br>Bakery: https://rentry.org/ldgcollage<br><br><span class="quote">&gt;Neighbours</span><br>https://rentry.org/ldg-lazy-getting<wbr>-started-guide#rentry-from-other-bo<wbr>ards<br><a href="//boards.4chan.org/aco/catalog#s=csdg" class="quotelink">&gt;&gt;&gt;/aco/csdg</a><br><a href="//boards.4chan.org/b/catalog#s=degen" class="quotelink">&gt;&gt;&gt;/b/degen</a><br><a href="//boards.4chan.org/b/catalog#s=realistic+parody" class="quotelink">&gt;&gt;&gt;/b/realistic+parody</a><br><a href="//boards.4chan.org/gif/catalog#s=vdg" class="quotelink">&gt;&gt;&gt;/gif/vdg</a><br><a href="//boards.4chan.org/d/catalog#s=ddg" class="quotelink">&gt;&gt;&gt;/d/ddg</a><br><a href="//boards.4chan.org/e/catalog#s=edg" class="quotelink">&gt;&gt;&gt;/e/edg</a><br><a href="//boards.4chan.org/h/catalog#s=hdg" class="quotelink">&gt;&gt;&gt;/h/hdg</a><br><a href="//boards.4chan.org/trash/catalog#s=slop" class="quotelink">&gt;&gt;&gt;/trash/slop</a><br><a href="//boards.4chan.org/vt/catalog#s=vtai" class="quotelink">&gt;&gt;&gt;/vt/vtai</a><br><a href="//boards.4chan.org/u/catalog#s=udg" class="quotelink">&gt;&gt;&gt;/u/udg</a><br><br><span class="quote">&gt;Local Text</span><br><a href="//boards.4chan.org/g/catalog#s=lmg" class="quotelink">&gt;&gt;&gt;/g/lmg</a><br><br><span class="quote">&gt;Maintain Thread Quality</span><br>https://rentry.org/debo',
#    'filename': 'highlights_g_106464276_1756866950',
#    'ext': '.webm',
#    'w': 2048,
#    'h': 1386,
#    'tn_w': 250,
#    'tn_h': 169,
#    'tim': 1756869559376323,
#    'time': 1756869559,
#    'md5': 'OPnChCyFuHiGz1fjb2kISA==',
#    'fsize': 3967230,
#    'resto': 0,
#    'bumplimit': 0,
#    'imagelimit': 0,
#    'semantic_url': 'ldg-local-diffusion-general',
#    'replies': 139,
#    'images': 45,
#    'omitted_posts': 134,
#    'omitted_images': 43,
#    'last_replies': [{'no': 106473453,
#      'now': '09/03/25(Wed)11:06:11',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473446" class="quotelink">&gt;&gt;106473446</a><br>When you type full body shot or prompt something regarding footwear',
#      'time': 1756911971,
#      'resto': 106469492},
#     {'no': 106473473,
#      'now': '09/03/25(Wed)11:08:19',
#      'name': 'Anonymous',
#      'com': 'Do flux loras still work with chroma',
#      'time': 1756912099,
#      'resto': 106469492},
#     {'no': 106473478,
#      'now': '09/03/25(Wed)11:08:43',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473431" class="quotelink">&gt;&gt;106473431</a><br><span class="quote">&gt;chroma is like bigasp</span><br>come on now lets not be disingenuous...<br>at least bigasp was trained at 1024x!',
#      'time': 1756912123,
#      'resto': 106469492},
#     {'no': 106473481,
#      'now': '09/03/25(Wed)11:09:07',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473264" class="quotelink">&gt;&gt;106473264</a>',
#      'filename': 'AnimateDiff_00285',
#      'ext': '.mp4',
#      'w': 720,
#      'h': 960,
#      'tn_w': 93,
#      'tn_h': 125,
#      'tim': 1756912147527579,
#      'time': 1756912147,
#      'md5': 'nSs8PWrTfeUys4wW/4S6VA==',
#      'fsize': 3631537,
#      'resto': 106469492},
#     {'no': 106473497,
#      'now': '09/03/25(Wed)11:10:16',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473365" class="quotelink">&gt;&gt;106473365</a><br><a href="#p106473394" class="quotelink">&gt;&gt;106473394</a><br><span class="quote">&gt;qwen isn&#039;t really as impressive as it should be</span><br>I&#039;d agree, but the alternatives in terms of prompt adherence and non-mangled hands/poses are kinda slim.<br>But the shocking amount of sameface and general lack of variance between seeds hurt the model a lot.<br>Picrel, 3 seeds, same prompt.',
#      'filename': 'seeds',
#      'ext': '.jpg',
#      'w': 4176,
#      'h': 2496,
#      'tn_w': 125,
#      'tn_h': 74,
#      'tim': 1756912216199957,
#      'time': 1756912216,
#      'md5': 'Gnb6cGPBhyfOqcPTQcg0jg==',
#      'fsize': 1364773,
#      'resto': 106469492}],
#    'last_modified': 1756912216},
#   {'no': 106473326,
#    'now': '09/03/25(Wed)10:52:09',
#    'name': 'Anonymous',
#    'sub': 'the web they took from us',
#    'com': 'fagbook js baseddevs are responsible for this decline',
#    'filename': 'blender',
#    'ext': '.png',
#    'w': 901,
#    'h': 997,
#    'tn_w': 225,
#    'tn_h': 250,
#    'tim': 1756911129440578,
#    'time': 1756911129,
#    'md5': 'PbhRM1+zs3Ms3POyP63rMw==',
#    'fsize': 635779,
#    'resto': 0,
#    'bumplimit': 0,
#    'imagelimit': 0,
#    'semantic_url': 'the-web-they-took-from-us',
#    'replies': 7,
#    'images': 1,
#    'omitted_posts': 2,
#    'omitted_images': 1,
#    'last_replies': [{'no': 106473421,
#      'now': '09/03/25(Wed)11:02:55',
#      'name': 'Anonymous',
#      'com': 'SAAR PLEASE WILL YOU LISTEN TO ME? YOU WILL NEED THE JAVASCRIPT SAAR',
#      'time': 1756911775,
#      'resto': 106473326},
#     {'no': 106473429,
#      'now': '09/03/25(Wed)11:03:42',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473395" class="quotelink">&gt;&gt;106473395</a><br><span class="quote">&gt;i don&#039;t like how it looks</span><br>fair.<br><span class="quote">&gt;Show it in 4:3</span><br>It&#039;s 2025, we use 16:9 nowadays',
#      'time': 1756911822,
#      'resto': 106473326},
#     {'no': 106473447,
#      'now': '09/03/25(Wed)11:05:44',
#      'name': 'Anonymous',
#      'com': 'The 2003 page graphics aren&#039;t loading, but I like the center column news with menus on the left and right. That was peak web format. Translates well to mobile too by just putting the menus up top.',
#      'time': 1756911944,
#      'resto': 106473326},
#     {'no': 106473483,
#      'now': '09/03/25(Wed)11:09:21',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473447" class="quotelink">&gt;&gt;106473447</a><br>yeah by the way because of the way we read <br><span class="quote">&gt;left to right</span><br>its good practice to put the sidebars on the right side, so the user can read/scan the main content easier',
#      'time': 1756912161,
#      'resto': 106473326},
#     {'no': 106473495,
#      'now': '09/03/25(Wed)11:10:09',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473326" class="quotelink">&gt;&gt;106473326</a><br><span class="quote">&gt;Menu on the sides or up top</span><br><span class="quote">&gt;Big block of plain text and hyperlinks</span><br>Based design, don&#039;t let jeets and women tell you you need more',
#      'time': 1756912209,
#      'resto': 106473326}],
#    'last_modified': 1756912209},
#   {'no': 106472197,
#    'now': '09/03/25(Wed)08:28:26',
#    'name': 'Anonymous',
#    'com': 'Nice seeing you, JerryRigEverything',
#    'filename': '1752588374902928',
#    'ext': '.png',
#    'w': 591,
#    'h': 191,
#    'tn_w': 250,
#    'tn_h': 80,
#    'tim': 1756902506923323,
#    'time': 1756902506,
#    'md5': 'ddM9dP6BdsO96qUbw4JDxg==',
#    'fsize': 30174,
#    'resto': 0,
#    'bumplimit': 0,
#    'imagelimit': 0,
#    'semantic_url': 'nice-seeing-you-jerryrigeverything',
#    'replies': 64,
#    'images': 8,
#    'omitted_posts': 59,
#    'omitted_images': 8,
#    'last_replies': [{'no': 106473457,
#      'now': '09/03/25(Wed)11:06:50',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473399" class="quotelink">&gt;&gt;106473399</a><br>I love how confidently some anons can say things so insane <br><br>- murdering people for their land is cool and normal<br>- I like that it happens still<br>- killing people and stealing their land is defeating terrorism<br>- if you resist people stealing your land you are a terrorist<br>- arabs are religious terrorists but &#039;gods chosen people doing a genocide&#039; are not<br><br>can&#039;t tell if JIDF or usa maga brainlet',
#      'time': 1756912010,
#      'resto': 106472197},
#     {'no': 106473468,
#      'now': '09/03/25(Wed)11:08:03',
#      'name': 'Anonymous',
#      'com': '<a href="#p106473457" class="quotelink">&gt;&gt;106473457</a><br>it&#039;s just a mentally ill edgy namefag, nothing new for 4chan man.',
#      'time': 1756912083,
#      'resto': 106472197},
#     {'no': 106473477,
#      'now': '09/03/25(Wed)11:08:40',
#      'name': 'Anonymous',
#      'com': '<a href="#p106472197" class="quotelink">&gt;&gt;106472197</a><br>JerryRIPEverything',
#      'time': 1756912120,
#      'resto': 106472197},
#     {'no': 106473486,
#      'now': '09/03/25(Wed)11:09:30',
#      'name': 'Anonymous',
#      'com': '<a href="#p106472197" class="quotelink">&gt;&gt;106472197</a><br>Is JerryKillAllTheJewEverything suicidal? I think he hates his life and wants to end it in the near future.',
#      'time': 1756912170,
#      'resto': 106472197},
#     {'no': 106473494,
#      'now': '09/03/25(Wed)11:10:01',
#      'name': 'Anonymous',
#      'com': '<a href="#p106472197" class="quotelink">&gt;&gt;106472197</a><br>based bald cripplefucker',
#      'time': 1756912201,
#      'resto': 106472197}],
#    'last_modified': 1756912201},
#   {'no': 106462054,
#    'now': '09/02/25(Tue)08:02:53',
#    'name': 'Anonymous',
#    'sub': '/desktop/',
#    'filename': '1756812839',
#    'ext': '.jpg',
#    'w': 1920,
#    'h': 1080,
#    'tn_w': 250,
#    'tn_h': 140,
#    'tim': 1756814573819029,
#    'time': 1756814573,
#    'md5': 'mCfgUs67jT/IUmvxnwBYUQ==',
#    'fsize': 616408,
#    'resto': 0,
#    'bumplimit': 0,
#    'imagelimit': 0,
#    'semantic_url': 'desktop',
#    'replies': 61,
#    'images': 24,
#    'omitted_posts': 56,
#    'omitted_images': 21,
#    'last_replies': [{'no': 106471375,
#      'now': '09/03/25(Wed)06:04:27',
#      'name': 'Anonymous',
#      'com': '<a href="#p106470326" class="quotelink">&gt;&gt;106470326</a><br>based madou monogatari 123',
#      'filename': 'file',
#      'ext': '.png',
#      'w': 1768,
#      'h': 1150,
#      'tn_w': 125,
#      'tn_h': 81,
#      'tim': 1756893867679274,
#      'time': 1756893867,
#      'md5': 'rluajV3IB9tv08PbZ7y3OA==',
#      'fsize': 166292,
#      'resto': 106462054},
#     {'no': 106472023,
#      'now': '09/03/25(Wed)07:57:13',
#      'name': 'Anonymous',
#      'com': '<a href="#p106470326" class="quotelink">&gt;&gt;106470326</a><br>but why?',
#      'time': 1756900633,
#      'resto': 106462054},
#     {'no': 106472025,
#      'now': '09/03/25(Wed)07:57:15',
#      'name': 'Anonymous',
#      'filename': '2023-08-08-192246_1024x768_scrot',
#      'ext': '.png',
#      'w': 1024,
#      'h': 768,
#      'tn_w': 125,
#      'tn_h': 93,
#      'tim': 1756900635325188,
#      'time': 1756900635,
#      'md5': 'a5zAksHL6F1B9ByWDrtAAg==',
#      'fsize': 869420,
#      'resto': 106462054},
#     {'no': 106473056,
#      'now': '09/03/25(Wed)10:25:22',
#      'name': 'Anonymous',
#      'com': '<a href="#p106469997" class="quotelink">&gt;&gt;106469997</a><br><span class="quote">&gt;So comfy, so cool.</span><br>thx. It&#039;s NEC VK27MD-J. I bought it for quite cheap locally, but it seems like a JDM model, it even has a Japanese keyboard.',
#      'time': 1756909522,
#      'resto': 106462054},
#     {'no': 106473493,
#      'now': '09/03/25(Wed)11:09:55',
#      'name': 'Anonymous',
#      'com': '<a href="#p106462143" class="quotelink">&gt;&gt;106462143</a><br>I like your terminal colors<br><a href="#p106465299" class="quotelink">&gt;&gt;106465299</a><br><a href="#p106466348" class="quotelink">&gt;&gt;106466348</a><br>gentoo chads<br><a href="#p106468125" class="quotelink">&gt;&gt;106468125</a><br>i love bitmappedd fonts. sometimes I wish I went back to a lower DPI monitor bc they are just way too small on my monitor now :(<br><a href="#p106472025" class="quotelink">&gt;&gt;106472025</a><br>I like the cat pic. also what wm is this, really like the pastel color scheme too',
#      'filename': 'out',
#      'ext': '.jpg',
#      'w': 3840,
#      'h': 2560,
#      'tn_w': 125,
#      'tn_h': 83,
#      'tim': 1756912195675006,
#      'time': 1756912195,
#      'md5': '4ZQkSEAKrSi6JAI8zijTOA==',
#      'fsize': 2027377,
#      'resto': 106462054}],
#    'last_modified': 1756912195}]}

# %%
page_1['threads'][1]['last_replies']
# Out:
# [{'no': 106473378,
#   'now': '09/03/25(Wed)10:57:36',
#   'name': 'Anonymous',
#   'com': '<a href="#p106471057" class="quotelink">&gt;&gt;106471057</a><br>Just install Linux from stretch and stop bitchin.',
#   'time': 1756911456,
#   'resto': 106471057},
#  {'no': 106473436,
#   'now': '09/03/25(Wed)11:04:25',
#   'name': 'Anonymous',
#   'com': '<a href="#p106473338" class="quotelink">&gt;&gt;106473338</a><br><span class="quote">&gt;The only one that matches this description is *KRRRRASHES*</span>',
#   'time': 1756911865,
#   'resto': 106471057},
#  {'no': 106473484,
#   'now': '09/03/25(Wed)11:09:23',
#   'name': 'Anonymous',
#   'com': 'It&#039;s Mint, it&#039;s been Mint for the past 10 years',
#   'time': 1756912163,
#   'resto': 106471057},
#  {'no': 106473492,
#   'now': '09/03/25(Wed)11:09:48',
#   'name': 'Anonymous',
#   'com': '<a href="#p106473436" class="quotelink">&gt;&gt;106473436</a><br>Are you on Debian 12 or another shitty LTS distro? KDE hasn&#039;t been unstable since 5.16.<br>Actually, scratch that. Since you&#039;re looking at ZorinOS (a distro stuck in early 2022) you probably are using outdated and broken packages.',
#   'time': 1756912188,
#   'resto': 106471057},
#  {'no': 106473503,
#   'now': '09/03/25(Wed)11:10:47',
#   'name': 'Anonymous',
#   'com': '<a href="#p106471114" class="quotelink">&gt;&gt;106471114</a><br>I like cinnamon because it&#039;s way lighter weight than GNOME or KDE, but it has a lot of the same fancy features that are easy to setup, and it&#039;s also customizable enough for my tastes. Xfce is great, it&#039;s lightweight and very flexible, but it&#039;s more minimal and requires more fiddling to get things like custom system sounds.<br>Just depends on whether you want a sane version of a &quot;modern&quot; desktop, or a more minimal, faster one.',
#   'time': 1756912247,
#   'resto': 106471057}]
