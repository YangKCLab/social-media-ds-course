# %%
import pandas as pd
import numpy as np
import json
import gzip

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'axes.axisbelow': True})

# %% [markdown]
# # Toy data

# %%
num_of_likes = pd.Series([5, 8, 10, 12, 15, 100, 200])
print(f"Mean value: {num_of_likes.mean()}")
print(f"Median value: {num_of_likes.median()}")
# Out:
# Mean value: 50.0
# Median value: 12.0

# %%
plt.hist(num_of_likes);
plt.xlabel("Number of likes")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Simulation

# %%
# Mean = 170 cm, Standard deviation = 10 cm
heights = np.random.normal(loc=170, scale=10, size=1000)
heights = np.clip(heights, 140, 210)  # keep within reasonable bounds

# %%
plt.hist(heights, bins=50)
plt.xlabel("Height (cm)")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(heights, bins=50)
plt.axvline(np.mean(heights), color="black")
plt.axvline(np.median(heights), color="red")
plt.xlabel("Height (cm)")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.boxplot(
    heights,
    orientation='horizontal'
);
plt.xlabel("Height (cm)");

# %%
plt.violinplot(
    heights,
    orientation='horizontal',
    showmeans=True,
#    showmedians=True
);
plt.xlabel("Height (cm)");

# %% [markdown]
# # Real data

# %%
with gzip.open("botwiki-2019_tweets.json.gz") as f:
    botwiki = json.load(f)

# %%
len(botwiki_df)
# Out:
# 698

# %%
botwiki_df = pd.DataFrame.from_records([item['user'] for item in botwiki])

# %%
plt.hist(botwiki_df.followers_count)
plt.xlabel("Number of followers")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
np.logspace(1, 6.2, num=20)
# Out:
# array([1.00000000e+01, 1.87795080e+01, 3.52669921e+01, 6.62296762e+01,
#        1.24376073e+02, 2.33572147e+02, 4.38637001e+02, 8.23738707e+02,
#        1.54694077e+03, 2.90507865e+03, 5.45559478e+03, 1.02453386e+04,
#        1.92402418e+04, 3.61322276e+04, 6.78545457e+04, 1.27427499e+05,
#        2.39302573e+05, 4.49398459e+05, 8.43948197e+05, 1.58489319e+06])

# %%
plt.hist(
    botwiki_df.followers_count,
    bins=np.logspace(1, 6.2, num=20)
);
plt.xlabel("Number of followers")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(
    botwiki_df.followers_count,
    bins=np.logspace(1, 6.2, num=20)
);
plt.xscale('log')
plt.xlabel("Number of followers")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(
    botwiki_df.followers_count,
    bins=np.logspace(1, 6.2, num=20)
);
plt.axvline(botwiki_df.followers_count.mean(), color="black")
plt.axvline(botwiki_df.followers_count.median(), color="red")

plt.xscale('log')
plt.xlabel("Number of followers")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
print(f"Mean value: {botwiki_df.followers_count.mean()}")
print(f"Median value: {botwiki_df.followers_count.median()}")
# Out:
# Mean value: 3511.8667621776503
# Median value: 81.0

# %%
plt.boxplot(
    botwiki_df.followers_count,
    orientation="horizontal"
)
plt.xlabel("Number of followers")
# Out:
# Text(0.5, 0, 'Number of followers')

# %%
plt.boxplot(
    botwiki_df.followers_count,
    orientation="horizontal"
)
plt.xscale("log")
plt.xlabel("Number of followers")
# Out:
# Text(0.5, 0, 'Number of followers')

# %%
plt.ecdf(
    botwiki_df.followers_count,
);
plt.xlabel("Number of followers")
plt.ylabel("CDF")
# Out:
# Text(0, 0.5, 'CDF')

# %%
plt.ecdf(
    botwiki_df.followers_count,
);
plt.xscale('log')
plt.xlabel("Number of followers")
plt.ylabel("CDF")
# Out:
# Text(0, 0.5, 'CDF')

# %%
plt.ecdf(
    botwiki_df.followers_count,
    complementary=True
);
plt.xscale('log')
plt.xlabel("Number of followers")
plt.ylabel("CCDF")
# Out:
# Text(0, 0.5, 'CCDF')
